# %% [markdown]
# <a href="https://colab.research.google.com/github/lazaliso/AAI614_-abirafeh-/blob/main/Practical_Exercise_Data_Scraping_Lise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the FluWatch page containing Table 2
url = "https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html"

# Fetch the HTML content of the page
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Find the table
table = soup.find("table", {"id": "t2"})
if not table:
    print("Table 2 not found on the page.")
    exit()

# Extract table rows
rows = table.find_all("tr")

# Extract headers
headers = [header.text.strip() for header in rows[0].find_all("th")]

# Extract data
data = []
for row in rows[1:]:
    cols = [col.text.strip() for col in row.find_all("td")]
    if cols:  # Avoid empty rows
        data.append(cols)

# Create a DataFrame
df = pd.DataFrame(data, columns=headers)

# Display the DataFrame
print("Scraped Data:")
print(df)

# Save DataFrame to a CSV file
df.to_csv("flu_watch_table2.csv", index=False)
print("Data saved to 'flu_watch_table2.csv'.")
# Out:
# Scraped Data:
#                                  Reporting Laboratory Flu Tested  \
# 0                                        Newfoundland       1299
# 1                                Prince Edward Island        307
# 2                                         Nova Scotia        864
# 3                                       New Brunswick       4271
# 4                                            Atlantic       6741
# 5                                  Région    Nord-Est       3551
# 6                         Québec-Chaudière-Appalaches       5028
# 7                                    Centre-du-Québec       5435
# 8                                      Montréal-Laval      16318
# 9                                     Ouest du Québec       4775
# 10                                         Montérégie       3288
# 11                                 Province of Québec      38395
# 12                                      Ottawa P.H.L.        360
# ...

# %%
import pandas as pd

# Load the scraped data
df = pd.read_csv('flu_watch_table2.csv')

# Display the first few rows of the DataFrame
df.head()
# Out:
#    Reporting Laboratory  Flu Tested  A(H1N1)pdm09 Positive  A(H3) Positive  \
# 0          Newfoundland      1299.0                    1.0             0.0
# 1  Prince Edward Island       307.0                   38.0             0.0
# 2           Nova Scotia       864.0                    0.0             0.0
# 3         New Brunswick      4271.0                   42.0             1.0
# 4              Atlantic      6741.0                   81.0             1.0
#
#    A(UnS) Positive  Total Flu A Positive  Total Flu B Positive  RSV Tested  \
# 0            113.0                 114.0                   1.0      1299.0
# 1              0.0                  38.0                   0.0       305.0
# 2             52.0                  52.0                   1.0       869.0
# 3            715.0                 758.0                   2.0      4274.0
# 4            880.0                 962.0                   4.0      6747.0
#
# ...

# %%
df.describe()
# Out:
#           Flu Tested  A(H1N1)pdm09 Positive  A(H3) Positive  A(UnS) Positive  \
# count      41.000000              41.000000       41.000000        41.000000
# mean     8069.682927             490.170732       28.536585       800.048780
# std     18488.739580            1322.212160       71.678831      1931.081186
# min        33.000000               0.000000        0.000000         0.000000
# 25%       435.000000               0.000000        0.000000         5.000000
# 50%      3062.000000              18.000000        1.000000       113.000000
# 75%      5435.000000             138.000000        9.000000       749.000000
# max    110399.000000            6609.000000      395.000000     10936.000000
#
#        Total Flu A Positive  Total Flu B Positive    RSV Tested  RSV Positive
# count             41.000000             41.000000      41.00000     41.000000
# mean            1318.829268             12.414634    7571.97561    344.878049
# ...
