# %% [markdown]
# <a href="https://colab.research.google.com/github/lazaliso/AAI614_-abirafeh-/blob/main/Week%203/Notebook3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 3.1: Practice with Data Collections*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%203/Notebook3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Source: Scraping with Python http://shop.oreilly.com/product/0636920034391.do

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1256274242
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1256274242&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-1
# #cite_note-actor-2
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-3
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# #cite_note-6
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-2
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-10
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-11
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-12
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-13
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-14
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-15
# /wiki/Footloose_(1984_film)
# #cite_note-bio-13
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-16
# #cite_note-bacon-7
# #cite_note-17
# #cite_note-18
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-19
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-13
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-20
# /wiki/Tremors_(1990_film)
# #cite_note-21
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-13
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-13
# /wiki/The_New_York_Times
# #cite_note-nyt94-22
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-23
# /wiki/A_Few_Good_Men_(film)
# #cite_note-24
# /wiki/Michael_Greif
# #cite_note-bio-13
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-13
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-13
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-25
# /wiki/Sleepers_(film)
# #cite_note-26
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-13
# /wiki/Losing_Chase
# #cite_note-austin-27
# /wiki/Digging_to_China
# #cite_note-bio-13
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-13
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-28
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-29
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-30
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-31
# /wiki/My_Dog_Skip_(film)
# #cite_note-32
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-33
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-34
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_05_(21267276740).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-35
# #cite_note-36
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-37
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-38
# #cite_note-39
# /wiki/The_Following
# #cite_note-40
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-41
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-42
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-43
# /wiki/Instagram
# #cite_note-44
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-45
# /wiki/EE_(telecommunications)
# #cite_note-46
# #cite_note-47
# #cite_note-48
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-49
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-50
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-51
# /wiki/File:Kevin_Bacon_2_SDCC_2014.jpg
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-11
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-52
# /wiki/Tracy_Pollan
# #cite_note-53
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-54
# #cite_note-55
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-56
# /wiki/Antireligion
# #cite_note-57
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-58
# #cite_note-59
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-60
# #cite_note-61
# #cite_note-62
# #cite_note-63
# /wiki/Apollo_13_(film)
# #cite_note-64
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-65
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-66
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-67
# /wiki/Denver_Film_Festival
# #cite_note-68
# /wiki/Phoenix_Film_Festival
# #cite_note-69
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-70
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-71
# /wiki/Seattle_International_Film_Festival
# #cite_note-72
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-6
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_10-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_11-0
# #cite_ref-cosmo91_11-1
# #cite_ref-12
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_13-0
# #cite_ref-bio_13-1
# #cite_ref-bio_13-2
# #cite_ref-bio_13-3
# #cite_ref-bio_13-4
# #cite_ref-bio_13-5
# #cite_ref-bio_13-6
# #cite_ref-bio_13-7
# #cite_ref-bio_13-8
# #cite_ref-bio_13-9
# #cite_ref-bio_13-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_14-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-15
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_16-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-17
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-18
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-19
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-20
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-21
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_22-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-23
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-24
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-25
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-26
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_27-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-28
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-29
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-30
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-31
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# /wiki/Template:Cite_news
# /wiki/Category:CS1_maint:_unfit_URL
# #cite_ref-32
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-33
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-34
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-35
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-36
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_37-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_38-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-39
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-40
# http://www.fox.com/the-following/
# #cite_ref-41
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-42
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-43
# http://baconbros.com/
# #cite_ref-44
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-45
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-46
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-47
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-48
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-49
# http://www.sixdegrees.org/
# #cite_ref-50
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-51
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-52
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-53
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-54
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-55
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-56
# #cite_ref-57
# https://www.foxnews.com/story/the-bacon-brothers-go-on-the-record
# #cite_ref-financialpost_58-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-59
# #cite_ref-60
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-61
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-62
# http://www.drawtheline.org/sign-now/
# #cite_ref-63
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-64
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-65
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-66
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-67
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-68
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-70
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-71
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-72
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# http://id.worldcat.org/fast/242183/
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://d-nb.info/gnd/124109659
# https://id.loc.gov/authorities/n88034930
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://nla.gov.au/anbd.aut-an36021861
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# http://data.bibliotheken.nl/id/thes/p147880998
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://lod.nl.go.kr/resource/KAC2020K8226
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://cantic.bnc.cat/registre/981061093903206706
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://www.idref.fr/067287832
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1256274242
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1_maint:_unfit_URL
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# https://wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Character_actor
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Black_Anvil
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now().strftime('%s'))
def getLinks(articleUrl):
    html = urlopen(f'http://en.wikipedia.org{articleUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# Streaming output truncated to the last 5000 lines.
# /wiki/Farm_Fresh_Food_%26_Pharmacy
# /wiki/Wegmans
# /wiki/Amazon_(company)
# /wiki/Digital_Insight
# /wiki/Lycos
# /wiki/VerticalNet
# /wiki/Modo_(wireless_device)
# /wiki/360networks
# /wiki/Dot-com_bubble
# /wiki/Social_networking_service
# /wiki/Forbes
# /wiki/American_Legacy
# /wiki/African-American_history
# /wiki/History_of_African_Americans_in_Kansas
# /wiki/Tuscarora_people
# /wiki/Christoph_von_Graffenried
# /wiki/Anne,_Queen_of_Great_Britain
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1763
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1790
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1783
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1729
# /wiki/List_of_acts_of_the_Northern_Ireland_Assembly_from_2008
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1906
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1896
# /wiki/Statute_Law_Revision_Act_1908
# /wiki/List_of_acts_of_the_Parliament_of_Scotland_from_1438
# /wiki/List_of_acts_of_the_Parliament_of_the_United_Kingdom_from_1866
# /wiki/9_Edw._7
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1739
# /wiki/List_of_acts_of_the_Parliament_of_Great_Britain_from_1798
# /wiki/Peerage_of_Great_Britain
# /wiki/Earl_of_Mansfield
# /wiki/Earl_of_Caithness
# /wiki/Peerage_of_Great_Britain
# /wiki/Peerage_of_Scotland
# /wiki/Welsh_peers_and_baronets
# /wiki/Earl_of_Carnarvon
# /wiki/Earl_Russell
# /wiki/Earl_of_Orford
# /wiki/Horace_Walpole
# /wiki/Kings_Lynn
# /wiki/River_Eden,_Cumbria
# /wiki/Wetheral
# /wiki/Brampton,_Carlisle,_Cumbria
# /wiki/Egremont,_Cumbria
# /wiki/List_of_Sites_of_Special_Scientific_Interest_in_Cumbria
# /wiki/Geological_Conservation_Review
# /wiki/Environmental_Protection_Act_1990
# /wiki/Emission_standard
# /wiki/Rights_of_nature
# /wiki/Cormac_Cullinan
# /wiki/ISBN_(identifier)
# /wiki/ISO_31-8
# /wiki/ISO/IEC_27000
# /wiki/Cloud_Infrastructure_Management_Interface
# /wiki/ISO_19600
# /wiki/ISO_15398
# /wiki/List_of_IEC_standards
# /wiki/IEC_61690
# /wiki/Daisy_Systems
# /wiki/Electronic_design_automation
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_15288
# /wiki/RKM_code
# /wiki/Metric_prefix
# /wiki/Joule
# /wiki/Steradian
# /wiki/Frequency
# /wiki/Transducer
# /wiki/Potentiometer
# /wiki/Memristor
# /wiki/S2CID_(identifier)
# /wiki/Review_article
# /wiki/Ethnography
# /wiki/Cross-cultural_studies
# /wiki/Cross-cultural_leadership
# /wiki/Doi_(identifier)
# /wiki/ISO_31-6
# /wiki/ISO_8178
# /wiki/C_Sharp_(programming_language)
# /wiki/ISO/IEC_9126
# /wiki/Algorithmic_efficiency
# /wiki/Central_processing_unit
# /wiki/Application-specific_integrated_circuit
# /wiki/ARM_Cortex-M
# /wiki/Computer_architecture
# /wiki/Emulator
# /wiki/Computer_hardware
# /wiki/Optical_disc
# /wiki/Universal_Disk_Format
# /wiki/Hierarchical_File_System_(IBM_MVS)
# /wiki/IBM
# /wiki/McGraw_Hill
# /wiki/Engrade
# /wiki/Common_Core_State_Standards_Initiative
# /wiki/The_Huffington_Post
# /wiki/Business_Insider
# /wiki/Insider_Inc.
# /wiki/Jeff_Bezos
# /wiki/Blue_Origin_NS-26
# /wiki/Blue_Ring
# /wiki/Outer_space
# /wiki/S2CID_(identifier)
# /wiki/Citation_impact
# /wiki/The_Royal_Society
# /wiki/Shigeru_Miyamoto
# /wiki/Nonlinear_gameplay
# /wiki/Castle_Wolfenstein
# /wiki/Commodore_64
# /wiki/OCLC_(identifier)
# /wiki/Catalog_card
# /wiki/Township_(United_States)
# /wiki/Washington_County,_Minnesota
# /wiki/Minnesota%27s_congressional_districts
# /wiki/Congressional_district
# /wiki/Thomas_Jefferson
# /wiki/Ayn_Rand
# /wiki/Hugo_Grotius
# /wiki/Wayback_Machine
# /wiki/Library_of_Congress
# /wiki/List_of_new_members_of_the_117th_United_States_Congress
# /wiki/Congressional_Equality_Caucus
# /wiki/David_Wu
# /wiki/Hanyu_Pinyin
# /wiki/MP4_file_format
# /wiki/ISO/IEC_4909
# /wiki/ISO/TR_11941
# /wiki/ISO_639
# /wiki/ISO_11992
# /wiki/ISO_25178
# /wiki/Prolog
# /wiki/Versatile_Video_Coding
# /wiki/ISO/IEC_9797-1
# /wiki/ISO_56000
# /wiki/Prolog
# /wiki/Meta-Object_Facility
# /wiki/Water_Resistant_mark
# /wiki/ISO_14031
# /wiki/ISO_base_media_file_format
# /wiki/Bink_Video
# /wiki/Code-excited_linear_prediction
# /wiki/MSU_Lossless_Video_Codec
# /wiki/Theora
# /wiki/Doom9
# /wiki/Digital_video
# /wiki/Telephony#Digital_telephony
# /wiki/Network_bandwidth
# /wiki/ISBN_(identifier)
# /wiki/ISO_19011
# /wiki/International_Standard_Musical_Work_Code
# /wiki/IS-IS
# /wiki/RFC_(identifier)
# /wiki/Christian_Huitema
# /wiki/Issy-les-Moulineaux
# /wiki/Departmental_Council_of_Hauts-de-Seine
# /wiki/President_(government_title)#Sub-national
# /wiki/Scotland
# /wiki/1864_in_Scotland
# /wiki/1747_in_Scotland
# /wiki/17_June
# /wiki/Pierre_F._C%C3%B4t%C3%A9
# /wiki/Quebec
# /wiki/Canada
# /wiki/Bibliography_of_Canada
# /wiki/Bibliography_of_Saskatchewan_history
# /wiki/Agriculture_in_Saskatchewan
# /wiki/Agriculture_in_Quebec
# /wiki/Saint-Laurent,_Quebec
# /wiki/Montreal
# /wiki/Shawinigan
# /wiki/List_of_regions_of_Quebec
# /wiki/Saguenay%E2%80%93Lac-Saint-Jean
# /wiki/Saint-F%C3%A9licien,_Quebec
# /wiki/List_of_towns_in_Quebec
# /wiki/Bonaventure_Regional_County_Municipality
# /wiki/Statistics_Canada
# /wiki/Electoral_district_(Canada)
# /wiki/Canadian_French
# /wiki/Proto-Romance_language
# /wiki/Voiced_dental_and_alveolar_plosives
# /wiki/Voiced_alveolo-palatal_affricate
# /wiki/Open_front_rounded_vowel
# /wiki/Voiceless_pharyngeal_fricative
# /wiki/Sioux_language
# /wiki/Anishinaabe_language
# /wiki/French_language_in_Canada
# /wiki/Norman_language
# /wiki/ISBN_(identifier)
# /wiki/ISO_2015
# /wiki/Rectangular_Micro_QR_Code
# /wiki/JBIG
# /wiki/Fuel_oil
# /wiki/ISO_3166
# /wiki/Country
# /wiki/Politics
# /wiki/Ethnic_democracy
# /wiki/Ulster_Scots_people
# /wiki/Battle_of_the_Boyne
# /wiki/Papal_States
# /wiki/Holy_orders_in_the_Catholic_Church
# /wiki/Matins
# /wiki/Te_Deum
# /wiki/Queen_Caroline_Te_Deum
# /wiki/Tra_le_fiamme_(Il_consiglio)
# /wiki/Movement_(music)
# /wiki/Riff
# /wiki/Bebop
# /wiki/Music_of_Washington,_D.C.#Jazz
# /wiki/Butch_Warren
# /wiki/Straight_No_Filter
# /wiki/Tone_Tantrum
# /wiki/Winner%27s_Circle
# /wiki/Album
# /wiki/Music_of_Argentina
# /wiki/Lali_(singer)
# /wiki/La_Naci%C3%B3n
# /wiki/Broadsheet
# /wiki/Wayback_Machine
# /wiki/European_Patent_Office
# /wiki/Patent_infringement
# /wiki/Fair_dealing
# /wiki/Copyright
# /wiki/Intellectual_property_protection_of_typefaces
# /wiki/Utility_model
# /wiki/Mozambique
# /wiki/International_Monetary_Fund
# /wiki/International_recognition_of_Kosovo
# /wiki/Foreign_relations_of_the_Republic_of_Kosovo
# /wiki/Provisional_Institutions_of_Self-Government
# /wiki/Administrative_divisions_of_Kosovo
# /wiki/Partition_of_Kosovo
# /wiki/Wolfgang_Ischinger
# /wiki/Rheinische_Post
# /wiki/Westdeutsche_Allgemeine_Zeitung
# /wiki/Funke_Mediengruppe
# /wiki/Ruhr
# /wiki/Recklinghausen_(district)
# /wiki/Mettmann_(district)
# /wiki/Bielefeld
# /wiki/Teutoburg_Forest
# /wiki/Napoleonic_Wars
# /wiki/Papal_States
# /wiki/Louis-Alexandre_Berthier
# /wiki/Battle_of_Teugen-Hausen
# /wiki/Maximilian_I_Joseph_of_Bavaria
# /wiki/Roman_Catholicism
# /wiki/Ministry_of_Jesus
# /wiki/Baptism_of_Jesus
# /wiki/Matthew_3
# /wiki/John_Barton_(theologian)
# /wiki/Oriel_and_Laing_Professor_of_the_Interpretation_of_Holy_Scripture
# /wiki/John_Wordsworth
# /wiki/Giles_of_Bridport
# /wiki/Aldhelm
# /wiki/Walter_Kerr_Hamilton
# /wiki/Francis_Mallet
# /wiki/John_Duport
# /wiki/Roger_Andrewes
# /wiki/Ian_H._White
# /wiki/British_Antarctic_Survey
# /wiki/Charles_Francis_Hall
# /wiki/Orcadas_Base
# /wiki/HMS_Erebus_(1826)
# /wiki/Captain_Nemo
# /wiki/Space_Strikers
# /wiki/Sunday_morning_cartoon
# /wiki/Breakfast_television
# /wiki/Copy_editing
# /wiki/Slate_(magazine)
# /wiki/Josh_Voorhees
# /wiki/Pulitzer_Center
# /wiki/Iona_Craig
# /wiki/Vice_(magazine)
# /wiki/Suroosh_Alvi
# /wiki/Israeli%E2%80%93Palestinian_conflict
# /wiki/All-Palestine_Government
# /wiki/All-Palestine_Protectorate
# /wiki/De_facto
# /wiki/Brussels_effect
# /wiki/Brussels_and_the_European_Union
# /wiki/Institutions_of_the_European_Union
# /wiki/Brussels_and_the_European_Union
# /wiki/Charles_Picqu%C3%A9
# /wiki/Louvain_School_of_Management
# /wiki/Ekiga
# /wiki/GTK
# /wiki/XVT
# /wiki/PureBasic
# /wiki/QuickBASIC
# /wiki/IntelliJ_IDEA
# /wiki/SharpDevelop
# /wiki/Comparison_of_integrated_development_environments
# /wiki/Microsoft_Windows
# /wiki/Singularity_(operating_system)
# /wiki/Garbage_collection_(computer_science)
# /wiki/International_Business_Times
# /wiki/Newsweek
# /wiki/Internet_Archive
# /wiki/STDU_Viewer
# /wiki/Jarir_Bookstore
# /wiki/Taiwan
# /wiki/Government_of_the_Republic_of_China
# /wiki/Uniform_Invoice_lottery
# /wiki/Taiwanese_tea_culture
# /wiki/Bancha
# /wiki/Rougui_tea
# /wiki/Russian_Caravan
# /wiki/Tea_in_the_United_Kingdom
# /wiki/Royal_Exchange,_London
# /wiki/Cornhill,_London
# /wiki/Flag_of_the_City_of_London
# /wiki/Flag_of_Middlesex
# /wiki/Historic_counties_of_England
# /wiki/Cheshire
# /wiki/Merseyside
# /wiki/Metropolitan_Borough_of_Knowsley
# /wiki/Lancashire
# /wiki/Mixed_(United_Kingdom_ethnicity_category)
# /wiki/London_Borough_of_Lambeth
# /wiki/Vestry
# /wiki/Parochial_church_council
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_19770
# /wiki/CAN_bus#CAN_lower-layer_standards
# /wiki/Atari_SIO
# /wiki/Serial_bus
# /wiki/Direct_Memory_Access
# /wiki/Ethernet
# /wiki/Fast_Ethernet
# /wiki/Autonegotiation
# /wiki/Medium_Attachment_Unit
# /wiki/DA-15
# /wiki/Ingram_Micro
# /wiki/Synnex
# /wiki/Net_income
# /wiki/Accounting_networks_and_associations
# /wiki/United_Kingdom
# /wiki/Irish_nationalism
# /wiki/Bezen_Perrot
# /wiki/World_War_II
# /wiki/Osprey_Publishing
# /wiki/Imprint_(trade_name)
# /wiki/White_paper
# /wiki/Bibliometrics
# /wiki/Scopus
# /wiki/New_York_Comic_Con
# /wiki/Rika_Ishikawa
# /wiki/Wayback_Machine
# /wiki/InformationWeek
# /wiki/CMP_Media
# /wiki/Informa
# /wiki/BBC_Radio
# /wiki/BBC_Radio_2
# /wiki/Joe_Lycett
# /wiki/Harry_Hill
# /wiki/Eric_Morecambe
# /wiki/Claudia_Winkleman
# /wiki/The_Oscars
# /wiki/List_of_films_shot_in_Harlem
# /wiki/Paris_Is_Burning_(film)
# /wiki/Women_in_Film_Crystal_%2B_Lucy_Awards
# /wiki/Mike_Farrell
# /wiki/Edmund_H._North
# /wiki/H.M.S._Defiant
# /wiki/CinemaScope
# /wiki/Pillarbox
# /wiki/Widescreen
# /wiki/28_mm_film
# /wiki/Nitrocellulose#Film
# /wiki/Acetone
# /wiki/Acetic_acid
# /wiki/Hour
# /wiki/Present
# /wiki/Immortality
# /wiki/Afterlife
# /wiki/Women_in_Buddhism
# /wiki/Lama
# /wiki/Saraha
# /wiki/Mandala
# /wiki/Khema
# /wiki/Jewish_Buddhist
# /wiki/Buddha_footprint
# /wiki/Five_hindrances
# /wiki/Brahmavihara
# /wiki/Tara_(Buddhism)
# /wiki/Thai_language
# /wiki/Northern_Economic_Corridor
# /wiki/Lampang_province
# /wiki/Krung_Thep_Maha_Nakhon
# /wiki/Japan
# /wiki/LGBTQ_rights_in_Japan
# /wiki/Gender_self-identification
# /wiki/Alliance_%2790/The_Greens
# /wiki/Green_League
# /wiki/The_Greens_(Israel)
# /wiki/Shlomtzion_(political_party)
# /wiki/Likud
# /wiki/Zehut
# /wiki/The_Jerusalem_Post
# /wiki/Makor_Rishon
# /wiki/Kol_Ha%27ir
# /wiki/Globes_(newspaper)
# /wiki/Yedioth_Ahronoth
# /wiki/LaMerhav
# /wiki/HaMashkif
# /wiki/HaBoker
# /wiki/Hebrew_language
# /wiki/Talmud
# /wiki/Isidore_Epstein
# /wiki/Kovno
# /wiki/Vilnius
# /wiki/Abraomas_Kulvietis
# /wiki/Duchy_of_Prussia
# /wiki/Brandenburg-Prussia
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_17025
# /wiki/ISO/IEC_7811
# /wiki/ISO_17100
# /wiki/ISO_7200
# /wiki/OpenDocument
# /wiki/Fiber_Distributed_Data_Interface
# /wiki/ISLISP
# /wiki/Comparative_Tracking_Index
# /wiki/IEC_60068
# /wiki/ISO/IEC_2022
# /wiki/Mixed_raster_content
# /wiki/ISO_11940
# /wiki/C%2B%2B
# /wiki/International_Electrotechnical_Commission
# /wiki/Montenegro
# /wiki/National_Museum_of_Montenegro
# /wiki/National_Library_of_Montenegro
# /wiki/KK_Lov%C4%87en_1947
# /wiki/%C5%BDabljak_Crnojevi%C4%87a
# /wiki/University_of_Montenegro_Faculty_of_Fine_Arts
# /wiki/Pobjeda
# /wiki/Jugoslavija_(magazine)
# /wiki/Zvyazda
# /wiki/Neues_Deutschland
# /wiki/Izvestia
# /wiki/All-Union_Radio
# /wiki/Nostalgia_for_the_Soviet_Union
# /wiki/France_24
# /wiki/Action_(French_TV_channel)
# /wiki/ADSL
# /wiki/Carrierless_amplitude_phase_modulation
# /wiki/Doi_(identifier)
# /wiki/Han_Xin_code
# /wiki/ISO_11170
# /wiki/International_Organization_for_Standardization
# /wiki/Classless_Inter-Domain_Routing
# /wiki/LAN
# /wiki/DOS
# /wiki/High_memory_area
# /wiki/IBM
# /wiki/Julie_Payette
# /wiki/Privy_Council_Office_(Canada)
# /wiki/Court_system_of_Canada#Federal_courts
# /wiki/Federal_Court_of_Appeal
# /wiki/Court_of_Appeal_of_Newfoundland_and_Labrador
# /wiki/Provincial_Court_of_Manitoba
# /wiki/Winnipeg
# /wiki/Greater_Fredericton
# /wiki/Maugerville_Parish,_New_Brunswick
# /wiki/Regional_service_commission#Kings_Regional_Service_Commission
# /wiki/Rothesay,_New_Brunswick
# /wiki/Sarah_Irving
# /wiki/Incumbent
# /wiki/ISSN_(identifier)
# /wiki/OpenDocument
# /wiki/ISO_45001
# /wiki/ISO_19092-2
# /wiki/STEP-NC
# /wiki/ISO/IEC_11801
# /wiki/ISO_3166-3
# /wiki/ISO_3166-1#VI-8
# /wiki/ISO_3166-1_alpha-2#PM
# /wiki/Spanish_language
# /wiki/Pro-drop_language
# /wiki/Lexicon
# /wiki/Dictionary
# /wiki/Egidio_Forcellini
# /wiki/Treviso
# /wiki/Carbonera,_Veneto
# /wiki/Caerano_di_San_Marco
# /wiki/Cappella_Maggiore
# /wiki/Pieve_di_Soligo
# /wiki/Catherine_of_Alexandria
# /wiki/Bishop
# /wiki/Philip_William_Otterbein
# /wiki/Wesleyanism
# /wiki/Christian_fundamentalism
# /wiki/Independent_Catholicism
# /wiki/Christianity_in_late_antiquity
# /wiki/History_of_the_Eastern_Orthodox_Church_under_the_Ottoman_Empire
# /wiki/Akribeia
# /wiki/Artos
# /wiki/Epiphany_(Christian)#Eastern_Christian_Churches
# /wiki/Georg_Philipp_Telemann
# /wiki/Franti%C5%A1ek_Brixi
# /wiki/Choral_Public_Domain_Library
# /wiki/Internet_Archive
# /wiki/Archive.today
# /wiki/Amnesty_International
# /wiki/Emergency_(organization)
# /wiki/Save_the_Children
# /wiki/Child_Development_Index
# /wiki/East_asia
# /wiki/List_of_Asian_and_Pacific_countries_by_GDP_(PPP)
# /wiki/List_of_sovereign_states_in_Europe_by_GDP_(nominal)_per_capita
# /wiki/List_of_endangered_languages_in_Europe
# /wiki/West_Frisian_language
# /wiki/Dutch_Low_Saxon
# /wiki/German_Sign_Language
# /wiki/Signed_Italian
# /wiki/Manually_coded
# /wiki/Miyakubo_Sign_Language
# /wiki/Icelandic_Sign_Language
# /wiki/Rossel_Island_Sign_Language
# /wiki/Kewa_language
# /wiki/Folopa_language
# /wiki/K%C3%A2te_language
# /wiki/Bimin_language
# /wiki/Yipma_language
# /wiki/Petats_language
# /wiki/Engan_languages
# /wiki/Zaparoan_languages
# /wiki/Chimbu%E2%80%93Wahgi_languages
# /wiki/Bola_language_(Austronesian)
# /wiki/Bosavi_languages
# /wiki/Sursurunga_language
# /wiki/X%C3%A2r%C3%A2c%C3%B9%C3%B9_language
# /wiki/Open-mid_front_unrounded_vowel
# /wiki/Retroflex_ejective_fricative
# /wiki/Ejective_consonant
# /wiki/Georgian_language
# /wiki/Voiceless_alveolar_fricative
# /wiki/Odia_language
# /wiki/Jajpur_district
# /wiki/Orissa_High_Court
# /wiki/West_Bengal
# /wiki/Kali_Puja
# /wiki/Pitha
# /wiki/Jaggery
# /wiki/Mango_float
# /wiki/Key_lime
# /wiki/List_of_citrus_diseases
# /wiki/Pratylenchus_vulnus
# /wiki/Global_Biodiversity_Information_Facility
# /wiki/ABCD_Schema
# /wiki/Data_exchange
# /wiki/Programming_language
# /wiki/Programming_language_design_and_implementation
# /wiki/Bootstrapping_(compilers)
# /wiki/Scheme_(programming_language)
# /wiki/MDL_(programming_language)
# /wiki/Massachusetts_Institute_of_Technology
# /wiki/East_Cambridge,_Cambridge,_Massachusetts
# /wiki/Charles_Bulfinch
# /wiki/Massachusetts_State_House
# /wiki/Boston
# /wiki/Franklin_County,_Massachusetts
# /wiki/2020_United_States_census
# /wiki/The_New_York_Times
# /wiki/Houston
# /wiki/Remington_Ranch,_Texas
# /wiki/Spring_Independent_School_District
# /wiki/Sunset_Heights,_Houston
# /wiki/Maplewood,_Houston
# /wiki/Inwood_Forest,_Houston
# /wiki/Bayou_Place
# /wiki/The_Woodlands_Mall
# /wiki/Hackett_Tower
# /wiki/Lone_Star_College%E2%80%93Montgomery
# /wiki/Tomball_Independent_School_District
# /wiki/San_Jacinto_College
# /wiki/Pearland_High_School
# /wiki/Pharr-San_Juan-Alamo_High_School
# /wiki/Edinburg_North_High_School
# /wiki/Donna_North_High_School
# /wiki/Muniz,_Texas
# /wiki/Hispanic_(U.S._Census)
# /wiki/Spanish_language
# /wiki/Official_language
# /wiki/Indigenous_language
# /wiki/Arctic_Council
# /wiki/Craiova_Group
# /wiki/List_of_countries_by_inequality-adjusted_HDI
# /wiki/Wage
# /wiki/Slow_movement_(culture)
# /wiki/McDonald%27s
# /wiki/Fast_Food_Nation
# /wiki/The_Omnivore%27s_Dilemma
# /wiki/McLibel_(film)
# /wiki/Fresh_(2009_film)
# /wiki/Will_Allen_(urban_farmer)
# /wiki/Richard_Montgomery_High_School
# /wiki/Paint_Branch_High_School
# /wiki/St._Andrew%27s_Episcopal_School_(Maryland)
# /wiki/Oldfields_School
# /wiki/Sparks_Glencoe,_Maryland
# /wiki/Catonsville,_Maryland
# /wiki/Ric_Ocasek
# /wiki/San_Francisco_Zoo
# /wiki/Cape_buffalo
# /wiki/Common_duiker
# /wiki/Antilopini
# /wiki/Artiodactyl
# /wiki/Black_duiker
# /wiki/Chamois
# /wiki/Giant_forest_hog
# /wiki/P%C3%A8re_David%27s_deer
# /wiki/Hirola
# /wiki/Eudorcas
# /wiki/Pudella_carlae
# /wiki/Oliver%27s_warty_pig
# /wiki/Peters%27s_duiker
# /wiki/Mongolian_gazelle
# /wiki/Water_deer
# /wiki/Hippocamelus
# /wiki/Hippotragus
# /wiki/East_African_oryx
# /wiki/Bud
# /wiki/Nelumbo
# /wiki/Epidermis_(botany)
# /wiki/Floral_formula
# /wiki/Vine
# /wiki/Vascular_tissue
# /wiki/Collenchyma
# /wiki/Cultivar_group
# /wiki/Gynoecium
# /wiki/Doi_(identifier)
# /wiki/International_Standard_Audiovisual_Number
# /wiki/ISO_11940
# /wiki/Topic_map
# /wiki/OpenDocument
# /wiki/Uniform_Type_Identifier
# /wiki/Universal_binary
# /wiki/Mac_OS_X_Tiger
# /wiki/Apple_Music
# /wiki/Sabih_Khan
# /wiki/Al_Gore
# /wiki/Weave_(protocol)
# /wiki/Google_Gadgets
# /wiki/Frank_v._Gaos
# /wiki/Rocky_Mountain_Bank_v._Google,_Inc.
# /wiki/Field_v._Google,_Inc.
# /wiki/Google_litigation
# /wiki/Safe_harbor_(law)
# /wiki/National_Oceanic_and_Atmospheric_Administration
# /wiki/Office_of_Oceanic_and_Atmospheric_Research
# /wiki/Office_of_Science
# /wiki/United_States_Marine_Corps_Warfighting_Laboratory
# /wiki/Networking_and_Information_Technology_Research_and_Development
# /wiki/Naval_Air_Weapons_Station_China_Lake
# /wiki/Inyo_County,_California
# /wiki/Santa_Clara_County,_California
# /wiki/San_Francisco_Bay_Area
# /wiki/New_Left
# /wiki/Buddhist_socialism
# /wiki/Socialist_ideology_of_the_Kuomintang
# /wiki/Pan-Asianism
# /wiki/Shandong_Peninsula
# /wiki/Shandong
# /wiki/Dongming_County
# /wiki/Luozhuang_District
# /wiki/Luozhuang_District
# /wiki/Wucheng_County
# /wiki/Pingyi_County
# /wiki/Jiyang_District,_Jinan
# /wiki/Dong%27e_County
# /wiki/Dezhou
# /wiki/Zibo
# /wiki/Jinxiang_County
# /wiki/Tai%27erzhuang_District
# /wiki/Shandong
# /wiki/Leling
# /wiki/Linyi
# /wiki/Lincang
# /wiki/Xianning
# /wiki/Kunming
# /wiki/Z%C3%BCrich
# /wiki/Appenzell
# /wiki/Del%C3%A9mont
# /wiki/List_of_states_with_limited_recognition
# /wiki/Raphael_Lemkin
# /wiki/Russian_Empire
# /wiki/Mongol_invasion_of_Kievan_Rus%27
# /wiki/Immigration_to_Ukraine
# /wiki/Ukrainian_dance
# /wiki/Elections_in_Ukraine
# /wiki/Paul_D%27Anieri
# /wiki/University_of_Florida_College_of_Liberal_Arts_and_Sciences
# /wiki/Weil_Hall
# /wiki/Samuel_Proctor_Oral_History_Program
# /wiki/Florida_Gators_football
# /wiki/Linebacker
# /wiki/Georgetown_Hoyas_football
# /wiki/Kennedy_Institute_of_Ethics_Journal
# /wiki/LCCN_(identifier)
# /wiki/Lutheran_Church_of_Christ_in_Nigeria
# /wiki/Chinese_Rhenish_Church_Hong_Kong_Synod
# /wiki/Evangelical_Lutheran_Church_in_Brunswick
# /wiki/African_Methodist_Episcopal_Church
# /wiki/Daniel_Coker
# /wiki/Francis_Asbury
# /wiki/Henry_Venn_(Church_Missionary_Society)
# /wiki/John_Venn
# /wiki/Probability
# /wiki/Experiment_(probability_theory)
# /wiki/Sample_space
# /wiki/Probability_space
# /wiki/Patrick_Billingsley
# /wiki/Chicago
# /wiki/Virginia,_Illinois
# /wiki/Eureka,_Illinois
# /wiki/Benson,_Illinois
# /wiki/United_States_Census_2010
# /wiki/Fort_Worth,_Texas
# /wiki/Urban_contemporary_music
# /wiki/Urban_adult_contemporary
# /wiki/African_Americans
# /wiki/New_Amsterdam
# /wiki/Mayor
# /wiki/Rainy_River_District
# /wiki/United_States
# /wiki/ISSN_(identifier)
# /wiki/International_Bank_Account_Number
# /wiki/British_Standard_Pipe
# /wiki/ISO_7001
# /wiki/ISO_12006
# /wiki/ISO_19092-2
# /wiki/ISO_25964
# /wiki/Graphical_Kernel_System
# /wiki/PHIGS
# /wiki/ISO/IEC_33001
# /wiki/Meta-Object_Facility
# /wiki/A440_(pitch_standard)
# /wiki/Middle_C
# /wiki/Frequency
# /wiki/Audible_frequency
# /wiki/Viola
# /wiki/Big_band
# /wiki/Plugg_(music)
# /wiki/Celtic_hip_hop
# /wiki/Folk_music
# /wiki/Switzerland
# /wiki/Doi_(identifier)
# /wiki/ArXiv
# /wiki/S2CID_(identifier)
# /wiki/Paperity
# /wiki/OCLC
# /wiki/Jay_Jordan
# /wiki/OCLC
# /wiki/Dewey_Decimal_Classification
# /wiki/Library_Journal
# /wiki/OCLC_(identifier)
# /wiki/Competition_law
# /wiki/Edward_Coke
# /wiki/John_Wenlock,_1st_Baron_Wenlock
# /wiki/St_Mary%27s_(Luton)
# /wiki/Athelstan_of_England
# /wiki/Guthred
# /wiki/Oswiu
# /wiki/Olaf_Guthfrithson
# /wiki/University_College_Cork
# /wiki/University_of_Limerick
# /wiki/Raheen,_County_Limerick
# /wiki/Limerick_Suburban_Rail
# /wiki/Birdhill_railway_station
# /wiki/Dublin%E2%80%93Cork_railway_line
# /wiki/The_Point_Luas_stop
# /wiki/Point_Village
# /wiki/Dublin_Area_Rapid_Transit
# /wiki/Steine_of_Dublin
# /wiki/Battle_of_Dublin
# /wiki/PS_Queen_Victoria_(1838)
# /wiki/PS_Keystone_State
# /wiki/American_Civil_War
# /wiki/Civil_War_Era_National_Cemeteries_MPS
# /wiki/Glendale_National_Cemetery
# /wiki/National_Register_of_Historic_Places_listings_in_Mecklenburg_County,_Virginia
# /wiki/National_Register_of_Historic_Places_listings_in_Portsmouth,_Virginia
# /wiki/National_Register_of_Historic_Places_listings_in_Nelson_County,_Virginia
# /wiki/Tyro,_Virginia
# /wiki/Lodebar,_Virginia
# /wiki/Roses_Mill,_Virginia
# /wiki/Unincorporated_community
# /wiki/S%C3%BDsla
# /wiki/Neutral_municipality
# /wiki/Niter%C3%B3i
# /wiki/Tupi_people
# /wiki/Market_economy
# /wiki/Anglo-Saxon_capitalism
# /wiki/Thatcherism
# /wiki/Family_values
# /wiki/Toryism
# /wiki/Distributism
# /wiki/Vincent_McNabb
# /wiki/Week_of_Prayer_for_Christian_Unity
# /wiki/Holy_water_in_Eastern_Christianity#Great_Blessing_of_Waters_at_Theophany
# /wiki/Paschal_cycle
# /wiki/Holy_Face_of_Jesus
# /wiki/Lausanne
# /wiki/Sarajevo
# /wiki/FK_Olimpik
# /wiki/2007%E2%80%9308_Bosnia_and_Herzegovina_Football_Cup
# /wiki/2003%E2%80%9304_Bosnia_and_Herzegovina_Football_Cup#Final
# /wiki/UEFA_Euro_2004_qualifying_Group_2
# /wiki/Dorinel_Munteanu
# /wiki/%C8%98tefan_Same%C8%99
# /wiki/Gheorghe_Hagi
# /wiki/Nevzat_G%C3%BCzel%C4%B1rmak
# /wiki/Kayseri_Erciyesspor
# /wiki/Be%C5%9Fikta%C5%9F_J.K._in_European_football
# /wiki/Helsingin_Jalkapalloklubi
# /wiki/Torino_F.C.
# /wiki/List_of_Serie_A_winning_managers
# /wiki/Heriberto_Herrera
# /wiki/William_Garbutt
# /wiki/Guido_Ara
# /wiki/2001%E2%80%9302_Serie_A
# /wiki/1935%E2%80%9336_Serie_A
# /wiki/1922%E2%80%9323_Prima_Divisione
# /wiki/1924%E2%80%9325_Prima_Divisione
# /wiki/Torino_F.C.
# /wiki/Spezia_Calcio
# /wiki/2006%E2%80%9307_Serie_B
# /wiki/Bologna_F.C._1909
# /wiki/1940%E2%80%9341_Bologna_F.C._1909_season
# /wiki/Bologna
# /wiki/Rome
# /wiki/Porticus_Aemilia
# /wiki/Museo_delle_anime_del_Purgatorio
# /wiki/Churches_of_Rome
# /wiki/Forum_of_Nerva
# /wiki/Corinthian_column
# /wiki/Limestone
# /wiki/Finland
# /wiki/North_Ostrobothnia
# /wiki/Pyh%C3%A4nt%C3%A4
# /wiki/Rantsila
# /wiki/Pyh%C3%A4joki
# /wiki/North_Ostrobothnia
# /wiki/Kuusamo
# /wiki/Russia
# /wiki/World_War_II_casualties
# /wiki/Soviet_Union
# /wiki/Michael_Hudson_(economist)
# /wiki/Immanuel_Wallerstein
# /wiki/World-systems_theory
# /wiki/World_population
# /wiki/Daniel_Quinn
# /wiki/YouTube
# /wiki/LG_Electronics
# /wiki/Acer_Inc.
# /wiki/Nepal_Telecom
# /wiki/Nepal_Stock_Exchange
# /wiki/Qatar_Exchange
# /wiki/World_Federation_of_Exchanges
# /wiki/CME_Group
# /wiki/Essendant
# /wiki/Mondelez_International
# /wiki/Exelon
# /wiki/Constellation_Energy
# /wiki/Conowingo_Dam
# /wiki/Baltimore_metropolitan_area
# /wiki/Bridgeport,_Connecticut
# /wiki/Long_Island_Sound
# /wiki/Ambrose_Channel
# /wiki/Ridgewood_Reservoir
# /wiki/Brooklyn_Waterworks
# /wiki/Freeport,_Long_Island
# /wiki/Meadowbrook_State_Parkway
# /wiki/Microsoft
# /wiki/The_Daily_Telegraph
# /wiki/Independent_Publishers_Guild
# /wiki/Copyright_Licensing_Agency
# /wiki/Nonprofit_organization
# /wiki/ISBN_(identifier)
# /wiki/Books_in_France
# /wiki/Incunabula_Short_Title_Catalogue
# /wiki/Codex
# /wiki/Oxford_University_Press
# /wiki/Sheldonian_Theatre
# /wiki/Old_Ashmolean_Building
# /wiki/Photography
# /wiki/Wolfgang_Franz_von_Kobell
# /wiki/List_of_mineralogists
# /wiki/Henry_James_Brooke
# /wiki/Brookite
# /wiki/Schist
# /wiki/Tephrite
# /wiki/Peridotite
# /wiki/Shoshonite
# /wiki/Teschenite
# /wiki/Greywacke
# /wiki/Basaltic_trachyandesite
# /wiki/Silica
# /wiki/2D_silica
# /wiki/Auxetics
# /wiki/Doi_(identifier)
# /wiki/RM-ODP
# /wiki/Zachman_Framework
# /wiki/View_model
# /wiki/Software_Architectural_Model
# /wiki/Software_engineering
# /wiki/View_model
# /wiki/Scenario_planning
# /wiki/ISBN_(identifier)
# /wiki/ISO_8178
# /wiki/ISO_5427
# /wiki/Code_page_899
# /wiki/%E2%84%9E
# /wiki/The_New_York_Times
# /wiki/David_Philipps
# /wiki/Relman_Morin
# /wiki/Walt_Bogdanich
# /wiki/Arthur_Daley_(sportswriter)
# /wiki/Barbara_Laker
# /wiki/Nigel_Jaquiss
# /wiki/Dan_Malone
# /wiki/Michael_D._Sallah
# /wiki/Mitch_Weiss
# /wiki/The_Wall_Street_Journal
# /wiki/The_Dispatch
# /wiki/Poynter_Institute
# /wiki/Times_Publishing_Company
# /wiki/Florida_Trend
# /wiki/Times_Publishing_Company
# /wiki/The_Tampa_Tribune
# /wiki/Deadline_Hollywood
# /wiki/Vox_Media
# /wiki/Oakland_Athletics
# /wiki/1975_Oakland_Athletics_season
# /wiki/Philadelphia_Athletics_18,_Cleveland_Indians_17_(1932)
# /wiki/2025_Cleveland_Guardians_season
# /wiki/2025_Arizona_Diamondbacks_season
# /wiki/2025_Texas_Rangers_season
# /wiki/2025_Kansas_City_Royals_season
# /wiki/1987_Kansas_City_Royals_season
# /wiki/Ross_Jones
# /wiki/Philadelphia_Phillies
# /wiki/Pitcher
# /wiki/Hiroshima_Toyo_Carp
# /wiki/1979_Japan_Series
# /wiki/1984_Nippon_Professional_Baseball_season
# /wiki/2009_Nippon_Professional_Baseball_season
# /wiki/1951_Nippon_Professional_Baseball_season
# /wiki/1960_Nippon_Professional_Baseball_season
# /wiki/Chunichi_Dragons
# /wiki/Day%C3%A1n_Viciedo
# /wiki/Kyocera_Dome
# /wiki/1978_Nippon_Professional_Baseball_season
# /wiki/1957_Nippon_Professional_Baseball_season
# /wiki/1997_Nippon_Professional_Baseball_season
# /wiki/1957_Nippon_Professional_Baseball_season
# /wiki/Andy_Miyamoto
# /wiki/1955_Japan_Series
# /wiki/2011_Nippon_Professional_Baseball_season
# /wiki/Yomiuri_Giants
# /wiki/Home_run
# /wiki/Lefty-righty_switch
# /wiki/Fastball
# /wiki/The_Neyer/James_Guide_to_Pitchers
# /wiki/Off-speed_pitch
# /wiki/Chief_Bender
# /wiki/Mule_Suttles
# /wiki/Pedro_Mart%C3%ADnez
# /wiki/Roger_Clemens
# /wiki/Fastball
# /wiki/Breaking_ball
# /wiki/Pitching_machine
# /wiki/Strikeout
# /wiki/Checked_swing
# /wiki/Shutout_(baseball)
# /wiki/American_League
# /wiki/Divisi%C3%B3n_de_Honor_de_B%C3%A9isbol
# /wiki/Mexican_League
# /wiki/Elitserien_(baseball)
# /wiki/China_National_Baseball_League
# /wiki/Federal_League
# /wiki/Mordecai_Brown
# /wiki/Randy_Johnson
# /wiki/Ed_Walsh
# /wiki/Charles_Comiskey
# /wiki/1919_World_Series
# /wiki/1961_Cincinnati_Reds_season
# /wiki/General_manager_(baseball)
# /wiki/Major_League_Baseball
# /wiki/Bill_Dinneen
# /wiki/St._Louis_Browns
# /wiki/2002_Baltimore_Orioles_season
# /wiki/Peter_Angelos
# /wiki/Major_League_Baseball
# /wiki/MLB_Mexico_City_Series
# /wiki/American_League_Division_Series
# /wiki/American_League_West
# /wiki/2010_New_York_Yankees_season
# /wiki/1993_New_York_Yankees_season
# /wiki/Home_(sports)
# /wiki/Citizens_Bank_Park
# /wiki/USA_Today
# /wiki/CBS_News_Radio
# /wiki/Public_broadcasting
# /wiki/TG4
# /wiki/8_Simple_Rules
# /wiki/J._D._Salinger
# /wiki/ISBN_(identifier)
# /wiki/Books_in_the_United_Kingdom
# /wiki/Northern_Irish_cuisine
# /wiki/Macanese_cuisine
# /wiki/Har_gow
# /wiki/Shellfish
# /wiki/Chicken_as_food
# /wiki/Mackerel_as_food
# /wiki/Escabeche
# /wiki/Bagoong
# /wiki/Kahawa_Sug
# /wiki/Egg_coffee
# /wiki/Latte_macchiato
# /wiki/Suppl%C3%AC
# /wiki/Chazuke
# /wiki/Rijsttafel
# /wiki/Lontong_sayur
# /wiki/Vietnamese_cuisine
# /wiki/Cuisine_of_the_Thirteen_Colonies
# /wiki/Kuwaiti_cuisine
# /wiki/Malian_cuisine
# /wiki/Guinea-Bissauan_cuisine
# /wiki/Macedonian_cuisine
# /wiki/Manipuri_cuisine
# /wiki/Swedish_cuisine
# /wiki/Root_vegetable
# /wiki/Colocasia_esculenta
# /wiki/Tarot
# /wiki/Trump_(card_games)
# /wiki/Priffe
# /wiki/Sheepshead_(card_game)
# /wiki/Smear_(card_game)
# /wiki/Wisconsin
# /wiki/Green_Bay_Blizzard
# /wiki/2014_Indoor_Football_League_season
# /wiki/U.S._Cellular_Center_(Cedar_Rapids,_Iowa)
# /wiki/Lakeside_Ballroom
# /wiki/Garnavillo_Township_Culvert
# /wiki/National_Register_of_Historic_Places_listings_in_Guam
# /wiki/Contributing_property
# /wiki/National_Register_of_Historic_Places_listings_in_Montana
# /wiki/National_Register_of_Historic_Places_listings_in_Rosebud_County,_Montana
# /wiki/City
# /wiki/Resource
# /wiki/Ecocentric
# /wiki/Environmental_activism_of_Al_Gore
# /wiki/Hardline_(subculture)
# /wiki/United_Kingdom
# /wiki/Charles_III
# /wiki/Lord_Nicholas_Windsor
# /wiki/Leopold_Windsor
# /wiki/Archbishop_of_Canterbury
# /wiki/Ceolnoth
# /wiki/Thomas_Arundel
# /wiki/Justin_Welby
# /wiki/Death_and_state_funeral_of_Elizabeth_II
# /wiki/Monarchy_of_New_Zealand#Cook_Islands,_Niue_and_territories
# /wiki/Monarchy_of_Antigua_and_Barbuda
# /wiki/Monarchy_of_Australia
# /wiki/Charles,_Prince_of_Wales
# /wiki/King_of_Saint_Kitts_and_Nevis
# /wiki/Outline_of_political_science#Politics_by_region
# /wiki/List_of_political_parties_in_Senegal
# /wiki/Reenu-Rew
# /wiki/Visa_policy_of_Senegal
# /wiki/Visa_requirements_for_Republic_of_the_Congo_citizens
# /wiki/Netherlands
# /wiki/Euro_Health_Consumer_Index
# /wiki/France
# /wiki/CFP_franc
# /wiki/Tuamotus
# /wiki/Nihiru
# /wiki/Rangiroa
# /wiki/Akamaru_Island
# /wiki/Angakauitai
# /wiki/Marutea_Nord
# /wiki/Aukena
# /wiki/Ravahere
# /wiki/Nengonengo
# /wiki/Raroia
# /wiki/Hikueru
# /wiki/Ravahere
# /wiki/Communes_of_France
# /wiki/Municipal_arrondissements_of_France
# /wiki/Paris_Centre
# /wiki/Music_in_Paris
# /wiki/Madonna
# /wiki/Jim_Pattison_Group
# /wiki/Finning
# /wiki/Caterpillar_777
# /wiki/V12_engine
# /wiki/List_of_WWII_Maybach_engines
# /wiki/ISBN_(identifier)
# /wiki/Book
# /wiki/Lists_of_books
# /wiki/Bibliotherapy
# /wiki/ISBN_(identifier)
# /wiki/ISO_13567
# /wiki/International_Standard_Music_Number
# /wiki/110_film
# /wiki/ISO/IEC_17024
# /wiki/Requirements_engineering
# /wiki/ISO/IEC_9126
# /wiki/ISO_13399
# /wiki/Common_Criteria
# /wiki/ISO/IEC_15504
# /wiki/Digital_Addressable_Lighting_Interface
# /wiki/Full_BASIC
# /wiki/STEP-NC
# /wiki/Milling_cutter
# /wiki/Eli_Whitney,_Jr.
# /wiki/Joseph_Story
# /wiki/John_E._Russell
# /wiki/George_B._Loring
# /wiki/Samuel_Dana_(Massachusetts_politician)
# /wiki/Anson_Burlingame
# /wiki/Massachusetts%27s_18th_congressional_district
# /wiki/Massachusetts%27s_6th_congressional_district
# /wiki/111th_United_States_Congress
# /wiki/Adam_Putnam
# /wiki/House_Republican_Conference
# /wiki/Joseph_W._Martin_Jr.
# /wiki/Alexander_H._Rice
# /wiki/William_W._Warren
# /wiki/Elijah_Brigham
# /wiki/Ernest_W._Roberts
# /wiki/Ambrose_Ranney
# /wiki/William_Parmenter
# /wiki/Richard_Neal
# /wiki/United_States_Government_Printing_Office
# /wiki/List_of_Jewish_members_of_the_United_States_Congress
# /wiki/Maryland
# /wiki/Freedmen
# /wiki/Atlantic_slave_trade
# /wiki/Slavery_among_Native_Americans_in_the_United_States
# /wiki/Woodland_period
# /wiki/Pre-Columbian_era
# /wiki/Mayoralty_in_the_United_States
# /wiki/List_of_longest-serving_mayors_in_the_United_States
# /wiki/Harrisburg,_Pennsylvania
# /wiki/Barnstable,_Massachusetts
# /wiki/Barnstable_Intermediate_School
# /wiki/Palmer_High_School_(Massachusetts)
# /wiki/Diman_Regional_Vocational_Technical_High_School
# /wiki/Bristol-Plymouth_Regional_Technical_School
# /wiki/Ninth_grade
# /wiki/Education_in_Afghanistan
# /wiki/Durrani_Empire
# /wiki/Muslim_conquests_of_Afghanistan
# /wiki/Turkestan
# /wiki/Organization_of_Turkic_States
# /wiki/Islamic_Republic_of_Afghanistan
# /wiki/Pashtun
# /wiki/Sufism
# /wiki/Secularism
# /wiki/Max_Weber
# /wiki/Gerontocracy
# /wiki/Louis_de_Bonald
# /wiki/Cicero
# /wiki/Somnium_Scipionis
# /wiki/Stoicism
# /wiki/Nominalism
# /wiki/Action_theory_(philosophy)
# /wiki/Scientism
# /wiki/Structuration_theory
# /wiki/Willard_Van_Orman_Quine
# /wiki/Bertrand_Russell
# /wiki/Nicholas_Griffin_(philosopher)
# /wiki/Doi_(identifier)
# /wiki/ANSI_C
# /wiki/IEC_60027
# /wiki/ISO/IEC_12207
# /wiki/Language_Of_Temporal_Ordering_Specification
# /wiki/ISO/IEC_8859-13
# /wiki/O
# /wiki/Phoenician_alphabet
# /wiki/Ancient_South_Arabian_script#Zabur_script
# /wiki/Voiceless_labiodental_fricative
# /wiki/Voiced_labial%E2%80%93velar_plosive
# /wiki/Voiceless_uvular_affricate
# /wiki/Voiceless_uvular%E2%80%93epiglottal_plosive
# /wiki/Voiced_uvular_affricate
# /wiki/Consonant
# /wiki/Voiced_alveolar_lateral_fricative
# /wiki/Voiceless_alveolar_non-sibilant_fricative
# /wiki/Mandarin_Chinese
# /wiki/Austronesian_languages
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/QR_code
# /wiki/Lexical_Markup_Framework
# /wiki/ISO_25964
# /wiki/ISO/IEC_2022
# /wiki/Windows-1258
# /wiki/Trademark_symbol
# /wiki/Lozenge_(shape)
# /wiki/Currency_symbol
# /wiki/Hong_Kong_dollar
# /wiki/Macanese_pataca
# /wiki/Bureau_de_change
# /wiki/HSBC
# /wiki/Wayback_Machine
# /wiki/Internet_Archive
# /wiki/ARChive_of_Contemporary_Music
# /wiki/John_H._Hammond
# /wiki/A_Hard_Rain%27s_a-Gonna_Fall
# /wiki/North_Country_Blues
# /wiki/John_Wesley_Harding
# /wiki/Melody_Maker
# /wiki/Duran_Duran
# /wiki/Vertigo_(U2_song)
# /wiki/Interscope_Records
# /wiki/OneRepublic
# /wiki/Human_(OneRepublic_album)
# /wiki/International_Federation_of_the_Phonographic_Industry
# /wiki/Music_Canada
# /wiki/Peer-to-peer_filesharing
# /wiki/The_Pirate_Bay
# /wiki/Wayback_Machine
# /wiki/Simon_Schwartzman#Collected_texts_of_Simon_Schwartzman
# /wiki/ISBN_(identifier)
# /wiki/ISO/IEC_27000-series
# /wiki/IEC_61970
# /wiki/Guidelines_for_the_Definition_of_Managed_Objects
# /wiki/International_Standard_Music_Number
# /wiki/ISO_10218
# /wiki/International_Standard_Identifier_for_Libraries_and_Related_Organizations
# /wiki/ISO_3166-1_alpha-2
# /wiki/Czechoslovakia
# /wiki/Sudetenland
# /wiki/Konrad_Henlein
# /wiki/Robert_William_Seton-Watson
# /wiki/Christopher_Seton-Watson
# /wiki/Fellowship
# /wiki/List_of_family_name_affixes
# /wiki/Lists_of_people_by_epithet
# /wiki/Naming_customs_of_Hispanic_America
# /wiki/ISBN_(identifier)
# /wiki/ISO_31-6
# /wiki/ISO_10303-21
# /wiki/Computer-aided_design
# /wiki/LibreCAD
# /wiki/Autodesk_Inventor
# /wiki/Magic_(software)
# /wiki/MEDUSA
# /wiki/Linux
# /wiki/Think_Blue_Linux
# /wiki/Linux_Router_Project
# /wiki/Pentoo
# /wiki/Qubes_OS
# /wiki/ArchBang
# /wiki/Yellow_Dog_Linux
# /wiki/Asahi_Linux
# /wiki/Solus_(operating_system)
# /wiki/GNU_Core_Utilities
# /wiki/Software_development
# /wiki/TEAF
# /wiki/Treasury
# /wiki/Waddesdon_Bequest
# /wiki/Epistle
# /wiki/Catholic_Church
# /wiki/Mithraism
# /wiki/Ute_mythology
# /wiki/Colorow_(Ute_chief)
# /wiki/Aspen,_Colorado
# /wiki/Roaring_Fork_River
# /wiki/Blue_Mesa_Reservoir
# /wiki/Geographic_coordinate_system
# /wiki/Mediterranean_Sea
# /wiki/Bibcode_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Unpaywall
# /wiki/Fork_(software_development)
# /wiki/Proprietary_software
# /wiki/Copyright_Act_of_1976
# /wiki/United_States_Senate
# /wiki/Chamber_of_Representatives_of_Burkina_Faso
# /wiki/Visa_policy_of_Burkina_Faso
# /wiki/Visa_requirements_for_Singaporean_citizens
# /wiki/Visa_policy_of_Ireland
# /wiki/Visa_policy_of_Cuba
# /wiki/Visa_requirements_for_Argentine_citizens
# /wiki/Nagaland
# /wiki/East_India_Company
# /wiki/Coat_of_arms_of_France
# /wiki/Kingdom_of_France
# /wiki/Timeline_of_French_history
# /wiki/FIFA_World_Cup
# /wiki/1950_FIFA_World_Cup
# /wiki/2018_and_2022_FIFA_World_Cup_bids
# /wiki/Antonio_Mateu_Lahoz
# /wiki/Slovak_Football_Association
# /wiki/Slovakia_national_under-19_football_team
# /wiki/1938_FIFA_World_Cup
# /wiki/Sweden_men%27s_national_football_team
# /wiki/Dallas
# /wiki/Round_Rock,_Texas
# /wiki/Coen_brothers
# /wiki/John_Irving
# /wiki/Trust_Exercise
# /wiki/A_Frolic_of_His_Own
# /wiki/William_Gaddis
# /wiki/Mao_II
# /wiki/ISBN_(identifier)
# /wiki/ISO_843
# /wiki/ISO/IEC_8859-7
# /wiki/KOI_character_encodings
# /wiki/Code_page_942
# /wiki/Stanford_Extended_ASCII
# /wiki/NeXT_character_set
# /wiki/%CB%98
# /wiki/Belarusian_language
# /wiki/Ukrainian_language
# /wiki/Russian_Sign_Language
# /wiki/Extinct_language
# /wiki/Northern_Territory,_Australia
# /wiki/University_of_Queensland_Press
# /wiki/Bicycle_and_Other_Poems
# /wiki/1970_in_Australian_literature
# /wiki/1917_in_Australian_literature
# /wiki/1917_in_literature
# /wiki/1918_in_poetry
# /wiki/Persian_poetry
# /wiki/Akram_Osman
# /wiki/Cyrillic
# /wiki/Tat_language_(Caucasus)
# /wiki/Karachay-Balkar
# /wiki/Uyghur_Arabic_alphabet
# /wiki/Romanization_of_Uyghur
# /wiki/%D9%88
# /wiki/Study_of_the_Hebrew_language
# /wiki/Tiberian_vocalization
# /wiki/Vav-consecutive
# /wiki/Biblical_Hebrew_orthography
# /wiki/Siloam_inscription
# /wiki/ISBN_(identifier)
# /wiki/Legal_Entity_Identifier
# /wiki/ISO_31-5
# /wiki/ISO_3166-1
# /wiki/ISO_3166-1_alpha-2#CK
# /wiki/United_Kingdom
# /wiki/Norman_conquest_of_England
# /wiki/Dorset
# /wiki/Seaborough
# /wiki/Corfe_Mullen
# /wiki/Corfe_Hills_School
# /wiki/The_Thomas_Hardye_School
# /wiki/Beaminster_Grammar_School
# /wiki/Grammar_school
# /wiki/Sudbury_school
# /wiki/Maths_school
# /wiki/Compositio_Mathematica
# /wiki/London_Mathematical_Society
# /wiki/International_Centre_for_Mathematical_Sciences
# /wiki/European_Mathematical_Society
# /wiki/Alexander_Kuznetsov_(mathematician)
# /wiki/Advances_in_Mathematics
# /wiki/Science_Citation_Index
# /wiki/Doi_(identifier)
# /wiki/Web_Content_Accessibility_Guidelines
# /wiki/Lexical_Markup_Framework
# /wiki/Antimagnetic_watch
# /wiki/ISO_3166-1
# /wiki/S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe
# /wiki/Ouadane
# /wiki/World_Heritage_Site
# /wiki/Caucasus
# /wiki/History_of_the_Ottoman_Empire
# /wiki/Algeria
# /wiki/Central_Intelligence_Agency
# /wiki/ISBN_(identifier)
# /wiki/SDMX
# /wiki/MP4_file_format
# /wiki/G.728
# /wiki/H.120
# /wiki/H.265
# /wiki/Netflix
# /wiki/Annihilation_(film)
# /wiki/Skydance_Media
# /wiki/Archer_(2009_TV_series)
# /wiki/Annie_Awards
# /wiki/Adelaide_Productions
# /wiki/Cartoon_Pizza
# /wiki/Cuppa_Coffee_Studios
# /wiki/Little_Einsteins
# /wiki/Jungle_Junction
# /wiki/List_of_programs_broadcast_by_Disney_Jr._(American_TV_channel)
# /wiki/List_of_programs_broadcast_by_ESPN
# /wiki/List_of_programs_broadcast_by_VH1
# /wiki/RuPaul%27s_Drag_Race
# /wiki/Ryan_Reynolds
# /wiki/Robert_Downey_Jr.
# /wiki/Andrew_Garfield
# /wiki/Antony_Sher
# /wiki/Willy_Russell
# /wiki/Blood_Brothers_(musical)
# /wiki/David_Cassidy
# /wiki/Donny_Osmond
# /wiki/Donny_and_Marie_Osmond_discography
# /wiki/Aaron_Osmond
# /wiki/Provo,_Utah
# /wiki/Inc._(magazine)
# /wiki/Los_Angeles_Times
# /wiki/East_Bay_Times
# /wiki/Alameda_County,_California
# /wiki/Midway,_Alameda_County,_California
# /wiki/Oakland,_California
# /wiki/Preservation_Park
# /wiki/Redwood_Regional_Park
# /wiki/African_American_Museum_and_Library_at_Oakland
# /wiki/Joseph_Knowland_State_Arboretum_and_Park
# /wiki/Arroyo_Viejo
# /wiki/Knowland_Park
# /wiki/Oakland_City_Hall
# /wiki/Morcom_Rose_Garden
# /wiki/YWCA_Building_(Oakland,_California)
# /wiki/California_College_of_the_Arts
# /wiki/Capp_Street_Project
# /wiki/Randall_Museum
# /wiki/Fort_Mason
# /wiki/Tadich_Grill
# /wiki/Pier_39
# /wiki/Ghirardelli_Chocolate_Company
# /wiki/San_Francisco_cable_car_system
# /wiki/Lowell_National_Historical_Park
# /wiki/Lewis_and_Clark_National_and_State_Historical_Parks
# /wiki/Oregon_Parks_and_Recreation_Department
# /wiki/Samuel_H._Boardman_State_Scenic_Corridor
# /wiki/Lewis_and_Clark_National_Wildlife_Refuge
# /wiki/Ontario_State_Recreation_Site
# /wiki/Willow_Creek_Wildlife_Area
# /wiki/Cape_Meares
# /wiki/Tillamook,_Oregon
# /wiki/Race_(U.S._Census)
# /wiki/South_African_Americans
# /wiki/Bah%C3%A1%CA%BC%C3%AD_Faith_in_the_United_States
# /wiki/Moojan_Momen
# /wiki/ISBN_(identifier)
# /wiki/ECMAScript_for_XML
# /wiki/Prontor-Compur
# /wiki/ISO_31-8
# /wiki/Fuel_oil
# /wiki/ISO_2711
# /wiki/Unified_Modeling_Language
# /wiki/OCR-B
# /wiki/ISO/IEC_9797-1
# /wiki/Renard_series
# /wiki/Romanization_of_Georgian
# /wiki/International_Standard_Audiovisual_Number
# /wiki/Isan_(disambiguation)
# /wiki/Yopno_language
# /wiki/Glottolog
# /wiki/Yale_language
# /wiki/Maybrat_language
# /wiki/Kimki_language
# /wiki/Berik_language
# /wiki/Kauwera_language
# /wiki/Tontemboan_language
# /wiki/Ilocano_language
# /wiki/Ati_language_(Philippines)
# /wiki/Teduray_language
# /wiki/Romblomanon_language
# /wiki/Kankanaey_language
# /wiki/Abra_(province)
# /wiki/La_Trinidad,_Benguet
# /wiki/Tuguegarao
# /wiki/DWCN_(Cagayan)
# /wiki/FM_broadcasting
# /wiki/Louis_Dorren
# /wiki/Palo_Alto,_California
# /wiki/Spanish_language
# /wiki/Wayback_Machine
# /wiki/Heritrix
# /wiki/Web_browser
# /wiki/Windows_10
# /wiki/Comparison_of_Microsoft_Windows_versions
# /wiki/MS-DOS
# /wiki/EOS_(8-bit_operating_system)
# /wiki/DOS_Plus
# /wiki/Floating-point_unit
# /wiki/IBM_POWER_architecture
# /wiki/Dynamic_random-access_memory
# /wiki/RC_time_constant
# /wiki/Ohm_(unit)
# /wiki/Charles_Wheatstone
# /wiki/Robert_Bunsen
# /wiki/Jean-Baptiste_Boussingault
# /wiki/Conservatoire_des_Arts_et_Metiers
# /wiki/INSA_Euro-M%C3%A9diterran%C3%A9e
# /wiki/Paris_Nanterre_University
# /wiki/University_of_Poitiers
# /wiki/Johann_Reuchlin
# /wiki/Catholicism
# /wiki/Catholic_Church_and_health_care
# /wiki/Orders,_decorations,_and_medals_of_the_Holy_See
# /wiki/Orders,_decorations,_and_medals_of_India
# /wiki/Orders,_decorations,_and_medals_of_Russia
# /wiki/United_States_law_enforcement_decorations
# /wiki/List_of_law_enforcement_agencies_in_the_District_of_Columbia
# /wiki/United_States_Armed_Forces
# /wiki/United_States_Marine_Corps_Aviation
# /wiki/Sikorsky_H-5
# /wiki/Sikorsky_S-52
# /wiki/ISBN_(identifier)
# /wiki/X3D
# /wiki/PSTricks
# /wiki/Radian
# /wiki/Turn_(geometry)
# /wiki/CNN
# /wiki/Alhurra
# /wiki/Libya_Alhurra_TV
# /wiki/Livestream
# /wiki/Chat_room
# /wiki/Ward_Christensen
# /wiki/WWIVnet
# /wiki/List_of_bulletin_board_system_software
# /wiki/Microsoft_Windows
# /wiki/Usage_share_of_operating_systems#Market_share_by_category
# /wiki/Gartner
# /wiki/Gaertner_(disambiguation)
# /wiki/Belva_Gaertner
# /wiki/Pasadena,_California
# /wiki/Pepperdine_University,_California_(CDP)
# /wiki/Pacific_Coast_Highway_(US)
# /wiki/Oxnard,_California
# /wiki/California_State_University,_Channel_Islands
# /wiki/California_Baptist_University
# /wiki/Faulkner_University
# /wiki/University_of_North_Alabama
# /wiki/Francis_Marion_University
# /wiki/Yancey_McGill
# /wiki/Republican_Party_(United_States)
# /wiki/1994_United_States_elections
# /wiki/Galusha_A._Grow
# /wiki/Idaho_Republican_Party
# /wiki/Idaho_Legislative_District_11
# /wiki/Gun_laws_in_Idaho
# /wiki/Law_of_Idaho
# /wiki/Demonym
# /wiki/Guinea_Bissau
# /wiki/4th_CPLP_Summit
# /wiki/Dulce_Pereira
# /wiki/Palmares_Cultural_Foundation
# /wiki/Candombl%C3%A9
# /wiki/Jorge_Amado
# /wiki/Miguel_Torga
# /wiki/Ad%C3%A9lia_Prado
# /wiki/Dorival_Caymmi
# /wiki/M%C3%A1rio_de_Andrade
# /wiki/Aesthetic
# /wiki/Index_of_sociopolitical_thinkers
# /wiki/Statolatry
# /wiki/Aventine_Secession_(20th_century)
# /wiki/November_1932_German_federal_election
# /wiki/German_National_People%27s_Party
# /wiki/Anti-communism
# /wiki/Anatoliy_Golitsyn
# /wiki/William_F._Buckley,_Jr.
# /wiki/The_Imaginative_Conservative
# /wiki/Paul_Weyrich
# /wiki/Amy_Coney_Barrett
# /wiki/Ballotpedia
# /wiki/The_Suffragist
# /wiki/Silent_Sentinels
# /wiki/Non-citizen_suffrage
# /wiki/First_Conference_of_the_International_Woman_Suffrage_Alliance
# /wiki/Statue_of_Elizabeth_Cady_Stanton
# /wiki/Women%27s_suffrage_in_the_Spanish_Civil_War_period
# /wiki/Women_in_Partido_Obrero_de_Unificaci%C3%B3n_Marxista
# /wiki/International_Anarchist_Congress_of_Amsterdam
# /wiki/Libertarian_socialism
# /wiki/Anti-capitalist
# /wiki/Private_property
# /wiki/Invisible_hand
# /wiki/Louis_de_Bonald
# /wiki/Popular_Liberal_Action
# /wiki/Senate_Republicans
# /wiki/Jean-Pierre_Fourcade
# /wiki/Jean-Baptiste_de_Vill%C3%A8le
# /wiki/French_Agrarian_and_Peasant_Party
# /wiki/Numa_Denis_Fustel_de_Coulanges
# /wiki/La_Nation_fran%C3%A7aise
# /wiki/French_Social_Party
# /wiki/War_in_the_Vend%C3%A9e
# /wiki/The_Scarlet_Pimpernel_(TV_series)
# /wiki/The_Triumph_of_the_Scarlet_Pimpernel
# /wiki/Hardcover
# /wiki/Nazi_book_burnings
# /wiki/Henri_Barbusse
# /wiki/Battle_of_Verdun
# /wiki/Meuse%E2%80%93Argonne_offensive
# /wiki/Naval_warfare_in_the_Mediterranean_during_World_War_I
# /wiki/Zurich
# /wiki/Horgen
# /wiki/Goldcoast_(Switzerland)
# /wiki/S40_(ZVV)
# /wiki/S20_(ZVV)
# /wiki/S10_(ZVV)
# /wiki/S30_(ZVV)
# /wiki/S24_(ZVV)
# /wiki/Zurich_S-Bahn
# /wiki/Basel_S-Bahn
# /wiki/L%C3%B6rrach-Stetten_station
# /wiki/Deutsche_Bahn
# /wiki/Arriva_Rail_London
# /wiki/Romford%E2%80%93Upminster_line
# /wiki/British_Rail_Class_710
# /wiki/Train_Protection_%26_Warning_System
# /wiki/Canadian_Rail_Operating_Rules
# /wiki/Cityflo_650_CBTC
# /wiki/Level_crossing_signals
# /wiki/Automatic_train_operation
# /wiki/Automated_guideway_transit
# /wiki/Maglev_(transport)
# /wiki/High-speed_rail_in_Canada
# /wiki/Edmonton
# /wiki/List_of_neighbourhoods_in_Edmonton
# /wiki/Edmonton_Transit_Service
# /wiki/Demographics_of_Edmonton
# /wiki/Salvadoran_Canadians
# /wiki/Saint-G%C3%A9d%C3%A9on-de-Beauce,_Quebec
# /wiki/Notre-Dame-des-Pins,_Quebec
# /wiki/Telephone_numbering_plan
# /wiki/France
# /wiki/Socotra
# /wiki/Gulf_of_Aden
# /wiki/Piracy_in_Somalia
# /wiki/Indo-Pakistani_War_of_1947%E2%80%931948
# /wiki/2015_Indian_counter-insurgency_operation_in_Myanmar
# /wiki/Defence_Space_Agency
# /wiki/Space_Activities_Bill
# /wiki/List_of_government_space_agencies
# /wiki/South_Korea
# /wiki/First_Republic_of_Korea
# /wiki/ISBN_(identifier)
# /wiki/International_Organization_for_Standardization
# /wiki/ISO_3166-3
# /wiki/Lists_of_countries_and_territories
# /wiki/Drug
# /wiki/Atropa_belladonna
# /wiki/Nabitan
# /wiki/4-AcO-DALT
# /wiki/RS134-49
# /wiki/5-Hydroxyindoleacetaldehyde
# /wiki/Norepinephrine
# /wiki/Zotepine
# /wiki/Paliperidone
# /wiki/SB-271046
# /wiki/5-Carboxamidotryptamine
# /wiki/CP-135807
# /wiki/Lysergic_acid_2-butyl_amide
# /wiki/Dibutyltryptamine
# /wiki/TiHKAL
# /wiki/4-HO-DPT
# /wiki/Avitriptan
# /wiki/Propranolol
# /wiki/Fluoxetine
# /wiki/Tracazolate
# /wiki/Flutazolam
# /wiki/Mebroqualone
# /wiki/Hexobarbital
# /wiki/Loreclezole
# /wiki/Ramelteon
# /wiki/PMID_(identifier)
# /wiki/Peer_review
# /wiki/Academic_conference
# /wiki/Preprint
# /wiki/ChemRxiv
# /wiki/PMC_(identifier)
# /wiki/List_of_open-source_health_software
# /wiki/GNU_General_Public_License
# /wiki/List_of_free_and_open-source_web_applications
# /wiki/Comparison_of_open-source_wireless_drivers
# /wiki/Mini_PCI
# /wiki/Synchronous_circuit
# /wiki/Digital_logic
# /wiki/Electromechanical_computer
# /wiki/Plugboard
# /wiki/Relay
# /wiki/Ozone
# /wiki/United_States_Environmental_Protection_Agency
# /wiki/United_States_v._Riverside_Bayview
# /wiki/Grady_v._Corbin
# /wiki/Double_Jeopardy_Clause
# /wiki/Elections_clause
# /wiki/Caliga_v._Inter_Ocean_Newspaper_Co.
# /wiki/Star_Athletica,_LLC_v._Varsity_Brands,_Inc.
# /wiki/Cosplay
# /wiki/Pantomime_horse
# /wiki/Mari_Lwyd
# /wiki/Edward_Jones_(harpist)
# /wiki/Galpin_Society
# /wiki/Archiv_Produktion
# /wiki/Sparrow_Records
# /wiki/Audrey_Assad
# /wiki/Amazon.com
# /wiki/Project_Gutenberg
# /wiki/The_Washington_Post
# /wiki/Voice_of_America
# /wiki/Wayback_Machine
# /wiki/ISSN_(identifier)
# /wiki/Open_Data_Protocol
# /wiki/POSIX
# /wiki/Illumos
# /wiki/OpenServer
# /wiki/Eunice_(software)
# /wiki/Ultrix
# /wiki/DECtape
# /wiki/PDP-6
# /wiki/DECmate
# /wiki/DECpc_AXP_150#DEC_2000_AXP
# /wiki/18-bit_computing
# /wiki/Computer_data_storage
# /wiki/CD
# /wiki/Concert
# /wiki/List_of_best-selling_albums
# /wiki/Michael_Jackson
# /wiki/Andrew_Watt_(record_producer)
# /wiki/Jared_Evan
# /wiki/Joey_Badass
# /wiki/DJ_Premier
# /wiki/Shady_Records
# /wiki/Virgin_Music_Group
# /wiki/Def_Jam_Recordings
# /wiki/070_Shake
# /wiki/Escapism_(Raye_song)
# /wiki/Mike_Sabath
# /wiki/DJ_Snake
# /wiki/Pitbull_(rapper)
# /wiki/DJ_Laz
# /wiki/Justin_Bieber
# /wiki/Carrie_Underwood
# /wiki/Texas_Stadium
# /wiki/Minneapolis
# /wiki/Laredo,_Texas
# /wiki/Webb_County
# /wiki/El_Paso,_Texas
# /wiki/El_Paso_Rhinos
# /wiki/Austin_Rise_FC
# /wiki/Lorenzo_de_Zavala_State_Archives_and_Library_Building
# /wiki/South_River_City,_Austin,_Texas
# /wiki/Leslie_Cochran
# /wiki/Emo%27s
# /wiki/CapMetro_Rail
# /wiki/French_Legation
# /wiki/Hyde_Park_(Austin,_Texas)
# /wiki/Deep_Eddy_Pool
# /wiki/Millett_Opera_House
# /wiki/Austin_City_Council_District_3
# /wiki/Democratic_Party_(United_States)
# /wiki/John_Edwards
# /wiki/Nathaniel_Macon
# /wiki/Strom_Thurmond
# /wiki/Gab_(social_network)
# /wiki/Jewish_ghettos_in_Europe
# /wiki/List_of_Nazi-era_ghettos
# /wiki/Einsatzgruppen
# /wiki/Auschwitz
# /wiki/Friedrich-Wilhelm_Kr%C3%BCger
# /wiki/Righteous_Among_the_Nations
# /wiki/Catholic_Herald
# /wiki/The_Great_Degeneration
# /wiki/ISBN_(identifier)
# /wiki/Pinyin
# /wiki/Thomas_Francis_Wade
# /wiki/Nanjing
# /wiki/Italy
# /wiki/Gulf_of_Taranto
# /wiki/Neapolitan_language
# /wiki/Catalan_language
# /wiki/Ladin_language
# /wiki/Andalusi_Romance
# /wiki/Doi_(identifier)
# /wiki/ISO_18245
# /wiki/ISO/IEC_8859-1
# /wiki/Code_page_770
# /wiki/Code_page_861
# /wiki/Code_page_869
# /wiki/Windows-1252
# /wiki/Lotus_Multi-Byte_Character_Set
# /wiki/%E2%80%B3
# /wiki/Longitude
# /wiki/HLA_(radio_station)
# /wiki/Korea_Research_Institute_of_Standards_and_Science
# /wiki/France
# /wiki/West_Francia
# /wiki/High_Middle_Ages
# /wiki/Carolingian_Renaissance
# /wiki/Louis_the_Pious
# /wiki/Ferdinand_II,_Holy_Roman_Emperor
# /wiki/Frederick_III,_Holy_Roman_Emperor
# /wiki/Leopold_III,_Duke_of_Austria
# /wiki/Albert_III_of_Austria
# /wiki/Maria_Theresa
# /wiki/Austro-Hungarian_florin
# /wiki/Gram
# /wiki/Orders_of_magnitude_(mass)
# /wiki/Bibcode_(identifier)
# /wiki/Digital_object_identifier
# /wiki/ISO_639-3
# /wiki/Photographic_Activity_Test
# /wiki/ISO_4157
# /wiki/ISO_3977
# /wiki/MPEG-D
# /wiki/Advanced_Video_Coding
# /wiki/JPEG_XT
# /wiki/VOB
# /wiki/VC-1
# /wiki/Motion_JPEG_2000
# /wiki/ISO_9660
# /wiki/Synthetic_file_system
# /wiki/Hybrid_kernel
# /wiki/C%2B%2B
# /wiki/C%2B%2B26
# /wiki/Comparison_of_Java_and_C%2B%2B
# /wiki/Comparison_of_programming_languages_(associative_arrays)
# /wiki/OptimJ
# /wiki/COIN-OR
# /wiki/Mathematica
# /wiki/Analyze_(imaging_software)
# /wiki/MountainsMap
# /wiki/Metrology
# /wiki/Outline_of_metrology_and_measurement
# /wiki/System_of_measurement
# /wiki/Ampere
# /wiki/Ohm%27s_law
# /wiki/Electrical_conductor
# /wiki/Electric_motor
# /wiki/Platen
# /wiki/Electrotyping
# /wiki/Electroplating
# /wiki/Surfactant
# /wiki/Quaternary_ammonium_salts
# /wiki/ESI-MS
# /wiki/Gas_chromatography%E2%80%93mass_spectrometry
# /wiki/Fire
# /wiki/The_Combustion_Institute
# /wiki/Gregory_Sivashinsky
# /wiki/Technion_%E2%80%93_Israel_Institute_of_Technology
# /wiki/Politehnica_University_of_Bucharest
# ...
# /wiki/ZeroNet
# /wiki/InterPlanetary_File_System
# /wiki/Flash_proxy
# /wiki/Hotspot_Shield
# /wiki/Ultrasurf
# /wiki/Vision_China_Times
# /wiki/David_Brophy_(historian)
# /wiki/Australian_National_University
# /wiki/Julie_Bishop
# /wiki/The_Australian
# /wiki/Christian_Kerr
# /wiki/Institute_of_Public_Affairs
# /wiki/Hypothetical
# /wiki/Theory
# /wiki/Abstraction
# /wiki/Mediatization_(media)
# /wiki/Intellectual_property#Rights
# /wiki/Fair_use
# /wiki/Bioprospecting
# /wiki/Fair_dealing
# /wiki/Public_domain
# /wiki/Comparison_of_free_software_for_audio
# /wiki/Cubase
# /wiki/Pan-Pot
# /wiki/SAE_Institute
# /wiki/Z%C3%BCrich
# /wiki/Kilchberg_railway_station
# /wiki/St%C3%A4fa
# /wiki/Arboretum
# /wiki/Wulp_Castle
# /wiki/Radio_Z%C3%BCrisee
# /wiki/St%C3%A4fa_railway_station
# /wiki/Lachen_railway_station
# /wiki/Canton_of_Z%C3%BCrich
# /wiki/French_language
# /wiki/French_language_in_Vietnam
# /wiki/Sercquiais
# /wiki/Idiolect
# /wiki/Yoda
# /wiki/Darth_Vader
# /wiki/Respeecher
# /wiki/Emilia_P%C3%A9rez
# /wiki/Harakiri_(1962_film)
# /wiki/I_Will_Buy_You
# /wiki/Keiji_Sada
# /wiki/Japan
# /wiki/Mount_Fuji
# /wiki/Hakone_Tozan_Line
# /wiki/Hakone_Tozan_Cable_Car
# /wiki/Funicular
# /wiki/Outline_of_transport
# /wiki/Train
# /wiki/Rail_transport_in_fiction
# /wiki/Coors_Light
# /wiki/Pabst_Blue_Ribbon
# /wiki/Houston
# /wiki/Bayou_City_Art_Festival
# /wiki/Memorial_Park,_Houston,_Texas
# /wiki/East_Downtown_Houston
# /wiki/University_of_Wisconsin%E2%80%93Madison
# /wiki/Charles_Van_Hise
# /wiki/Charles_L._Drake
# /wiki/Eldridge_M._Moores
# /wiki/United_States
# /wiki/2028_Summer_Olympics
# /wiki/Los_Angeles
# /wiki/Doi_(identifier)
# /wiki/MP4_file_format
# /wiki/MPEG-4_Part_2
# /wiki/MP3
# /wiki/Bloomberg_BusinessWeek
# /wiki/Robert_Kolker
# /wiki/Associated_Press
# /wiki/United_States_National_Security_Council
# /wiki/United_States_Homeland_Security_Council
# /wiki/White_House_Communications_Director
# /wiki/Kevin_Sullivan_(communications_professional)
# /wiki/David_Gergen
# /wiki/Carol_Costello
# /wiki/PR_Newswire
# /wiki/The_Pittsburgh_Press
# /wiki/Pittsburgh
# /wiki/Pittsburgh_Post-Gazette
# /wiki/Allegheny_Democrat
# /wiki/Pennsylvania
# /wiki/Grouse
# /wiki/Freckled_duck
# /wiki/Ankonetta
# /wiki/Biziura
# /wiki/Subfossil
# /wiki/Doi_(identifier)
# /wiki/PLoS_Biology
# /wiki/MEDLINE
# /wiki/Health_care
# /wiki/World_Health_Organization
# /wiki/Eradication_of_infectious_diseases
# /wiki/John_Franklin_Enders
# /wiki/Bill_Clinton
# /wiki/DeMolay_International
# /wiki/Sect
# /wiki/Cult
# /wiki/Bob_Larson
# /wiki/Jessica_Williams_(actress)
# /wiki/Primetime_Emmy_Award_for_Outstanding_Supporting_Actress_in_a_Comedy_Series
# /wiki/1986_in_television
# /wiki/1939_in_television
# /wiki/Ray_Stevens
# /wiki/Boogity_Boogity
# /wiki/David_Kent_(historian)
# /wiki/Turramurra,_New_South_Wales
# /wiki/Therapeutic
# /wiki/Electroconvulsive_therapy
# /wiki/Galvanism
# /wiki/Electrotherapy
# /wiki/Neuromuscular_diagnostics
# /wiki/Evoked_potential
# /wiki/Brainstem
# /wiki/Dorsal_tegmental_nucleus
# /wiki/Doi_(identifier)
# /wiki/Common_Logic
# /wiki/ISO/IEC_11179
# /wiki/XML_Metadata_Interchange
# /wiki/Object_Constraint_Language
# /wiki/Mixed_raster_content
# /wiki/ISO_14224
# /wiki/ISO_base_media_file_format
# /wiki/RealVideo
# /wiki/Wireless_Application_Protocol_Bitmap_Format
# /wiki/RealAudio
# /wiki/Original_Sound_Quality
# /wiki/Audio_compression_(data)
# /wiki/Compressed_data_structure
# /wiki/Redundancy_(information_theory)
# /wiki/Stationary_process
# /wiki/Medical_statistics
# /wiki/Correlogram
# /wiki/Exponential_smoothing
# /wiki/Bayesian_probability
# /wiki/AFM_Smith
# /wiki/Visitor
# /wiki/Lieutenant_governor_of_Ontario
# /wiki/Governor_of_Saint_Helena
# /wiki/Governor_of_Anguilla
# /wiki/List_of_governors_of_Uganda
# /wiki/Prime_Minister_of_Egypt
# /wiki/Nile
# /wiki/Owen_Falls
# /wiki/Buwenge_General_Hospital
# /wiki/Geographic_coordinate_system
# /wiki/Circle_of_latitude
# /wiki/Callippic_cycle
# /wiki/Timocharis
# /wiki/Theon_of_Smyrna
# /wiki/History_of_arithmetic
# /wiki/Geometry
# /wiki/Mathematics
# /wiki/Western_world
# /wiki/Alfred_Thayer_Mahan
# /wiki/USS_James_Adger
# /wiki/Trent_Affair
# /wiki/Royal_Mail_steamer
# /wiki/SS_Snaefell_(1863)
# /wiki/Houqua_(clipper)
# /wiki/New_York_City
# /wiki/Bangkok
# /wiki/Delhi
# /wiki/Sayyid_Dynasty
# /wiki/Firuz_Shah_Tughlaq
# /wiki/Ghiyas-ud-Din_Tughlaq_II
# /wiki/Tughlaq_dynasty
# /wiki/ISBN_(identifier)
# /wiki/LCEVC
# /wiki/S2CID_(identifier)
# /wiki/List_of_style_guides#Academic
# /wiki/Garner%27s_Modern_English_Usage
# /wiki/Merriam-Webster%27s_Dictionary_of_English_Usage
# /wiki/ISBN_(identifier)
# /wiki/TC_46/SC_9
# /wiki/Information_centre
# /wiki/Outdoor_literature
# /wiki/Walden_Pond
# /wiki/Lake_Wicwas
# /wiki/Country_Pond
# /wiki/Gilford,_New_Hampshire
# /wiki/1870_United_States_census
# /wiki/New_Brunswick,_New_Jersey
# /wiki/Wayback_Machine
# /wiki/Alexa_Internet
# /wiki/Amazon_Elastic_Block_Store
# /wiki/Oracle_Cloud
# /wiki/Linode
# /wiki/F._Thomson_Leighton
# /wiki/Society_for_Industrial_and_Applied_Mathematics
# /wiki/List_of_arbitrary-precision_arithmetic_software
# /wiki/ISC_license
# /wiki/Open-source_software_advocacy
# /wiki/Proprietary_software
# /wiki/Open-source-software_movement
# /wiki/Kuali
# /wiki/For-profit
# /wiki/Human_resource_management
# /wiki/Undergraduate_education
# /wiki/French_Education_System
# /wiki/All_Saints%27_Day
# /wiki/Ash_Wednesday
# /wiki/Christian_Today
# /wiki/Sky_News
# /wiki/WeatherVision
# /wiki/SCORE_(television)
# /wiki/List_of_television_stations_in_Mexico
# /wiki/Tepotzotl%C3%A1n
# /wiki/Codex_Osuna
# /wiki/Macuilxochitl
# /wiki/Quetzalcoatl
# /wiki/Mictlanpachecatl
# /wiki/South_wind
# /wiki/Sirocco
# /wiki/Ponente
# /wiki/Ostro
# /wiki/Croatian_language
# /wiki/Languages_of_Italy
# /wiki/Indo-Aryan_languages
# /wiki/Runic_inscriptions
# /wiki/Z
# /wiki/Swahili_language
# /wiki/Euphrase_Kezilahabi
# /wiki/Poet
# /wiki/Audience
# /wiki/Crossover_(fiction)
# /wiki/Jules_Lema%C3%AEtre
# /wiki/University_of_Grenoble
# /wiki/L%C3%A9a_Roback
# /wiki/Marxism-Leninism
# /wiki/ISBN_(identifier)
# /wiki/International_Bank_Account_Number
# /wiki/ISO_31-6
# /wiki/ISO_21001
# /wiki/ISO_3977
# /wiki/ISO/IEC_6523
# /wiki/ISO_45001
# /wiki/Accord_on_Fire_and_Building_Safety_in_Bangladesh
# /wiki/Memorandum_of_understanding
# /wiki/Bilateralism
# /wiki/World_War_II
# /wiki/Early_modern_period
# /wiki/Artisans
# /wiki/Pastoral
# /wiki/Doric_Greek
# /wiki/Music_of_ancient_Greece
# /wiki/Aristotelian_ethics
# /wiki/Rhetoric_to_Alexander
# /wiki/Tacitus
# /wiki/Propaganda
# /wiki/Uro%C5%A1_Predi%C4%87
# /wiki/Jovan_Cviji%C4%87
# /wiki/Monument_to_Jovan_Cviji%C4%87
# /wiki/Belgrade
# /wiki/Vra%C4%8Dar
# /wiki/Lipljan
# /wiki/Central_European_Time
# /wiki/Uzhhorod
# /wiki/Geographic_coordinate_system
# /wiki/145th_meridian_east
# /wiki/Australia
# /wiki/Canberra
# /wiki/National_Gallery_of_Australia
# /wiki/Australia_Forum
# /wiki/Lindsay_Pryor_National_Arboretum
# /wiki/National_Arboretum_Canberra
# /wiki/Springbank_Island
# /wiki/Spinnaker_Island_(Lake_Burley_Griffin)
# /wiki/Corin_Dam
# /wiki/Lake_Ginninderra
# /wiki/Molonglo_River
# /wiki/Jerrara_Creek
# /wiki/Crookwell_River
# /wiki/Northern_Rivers
# /wiki/Toona_ciliata
# /wiki/Tropicos
# /wiki/South_America
# /wiki/Doi_(identifier)
# /wiki/ISO_732
# /wiki/CAN_bus#CAN_lower-layer_standards
# /wiki/CANopen
# /wiki/Boolean_data_type
# /wiki/Null-terminated_string
# /wiki/Borland_Turbo_C
# /wiki/Turbo_C_Sharp
# /wiki/Integrated_development_environment
# /wiki/ISSN_(identifier)
# /wiki/ISO_13485
# /wiki/SQL
# /wiki/ISO_31
# /wiki/ISO_1000
# /wiki/ISO_6438
# /wiki/Mac_OS_Inuit
# /wiki/Mac_OS_Romanian_encoding
# /wiki/ISO_5426
# /wiki/ISO_8501-1
# /wiki/ISO_14644
# /wiki/Object_Constraint_Language
# /wiki/International_Standard_Recording_Code
# /wiki/ISO/IEC_8859-15
# /wiki/English_language
# /wiki/ISBN_(identifier)
# /wiki/ISO_860
# /wiki/ISO/TR_11941
# /wiki/ISO_3864
# /wiki/Romanization_of_Georgian
# /wiki/ASMO_449
# /wiki/Windows-1254
# /wiki/%C3%99
# /wiki/%C3%99
# /wiki/Vietnamese_language
# /wiki/Religion_in_Vietnam
# /wiki/V-pop
# /wiki/Serbian_pop
# /wiki/Traditional_pop
# /wiki/Futurepop
# /wiki/Kawaii_future_bass
# /wiki/UK_funky
# /wiki/Speed_garage
# /wiki/ISBN_(identifier)
# /wiki/JBIG
# /wiki/ISO_26000
# /wiki/Rule_of_law
# /wiki/Thomas_Paine
# /wiki/Ralph_Waldo_Emerson
# /wiki/James_Buchanan_Eads
# /wiki/Thomas_Paine
# /wiki/Second_Congress_of_Rastatt
# /wiki/Antoine_Christophe_Merlin
# /wiki/National_Convention
# /wiki/Cult_of_the_Supreme_Being
# /wiki/Jean_Th%C3%A9ophile_Victor_Leclerc
# /wiki/Claire_Lacombe
# /wiki/William_Doyle_(historian)
# /wiki/University_of_Oxford
# /wiki/Chinese_room
# /wiki/Regulation_of_artificial_intelligence
# /wiki/Policy
# /wiki/Harold_Lasswell
# /wiki/Seymour_Martin_Lipset
# /wiki/William_F._Willoughby
# /wiki/Ira_Katznelson
# /wiki/Peter_H._Odegard
# /wiki/Columbia_University
# /wiki/Edmund_S._Morgan
# /wiki/Perry_Miller
# /wiki/Colonial_history_of_the_United_States
# /wiki/Healthcare_in_the_United_States
# /wiki/Healthcare_in_Seychelles
# /wiki/List_of_hospitals_in_Egypt
# /wiki/List_of_hospitals_in_the_Maldives
# /wiki/List_of_hospitals_in_Georgia_(country)
# /wiki/Kingdom_of_Kartli-Kakheti
# /wiki/Battle_of_Krtsanisi
# /wiki/Solomon_II_of_Imereti
# /wiki/Alexander_II_of_Kakheti
# /wiki/Solomon_I_of_Imereti
# /wiki/Simon_II_of_Kartli
# /wiki/Suleiman_I_of_Persia
# /wiki/Ehsan_Yarshater
# /wiki/Mirza_Mohammad_Taqi_Sepehr
# /wiki/Qajar_Iran
# /wiki/Persian_Constitutional_Revolution
# /wiki/Persian_Constitution_of_1906
# /wiki/1949_Iranian_Constituent_Assembly_election
# /wiki/ISBN_(identifier)
# /wiki/X3D
# /wiki/International_Standard_Name_Identifier
# /wiki/SQL
# /wiki/SQL/JRT
# /wiki/SQL_reserved_words
# /wiki/SQL_syntax
# /wiki/Relational_algebra
# /wiki/Null_(SQL)#Comparisons_with_NULL_and_the_three-valued_logic_.283VL.29
# /wiki/Witold_Lipski
# /wiki/Warsaw
# /wiki/Milk_bar
# /wiki/Upstate_New_York
# /wiki/Henry_Hudson
# /wiki/Piracy
# /wiki/Privateer
# /wiki/Piracy_Act_1717
# /wiki/List_of_acts_of_the_5th_session_of_the_8th_Parliament_of_Great_Britain
# /wiki/European_Communities
# /wiki/Treaty_of_Paris_(1951)
# /wiki/Europe_Declaration
# /wiki/Switzerland%E2%80%93European_Union_relations
# /wiki/Armenia%E2%80%93Switzerland_relations
# /wiki/Armenia%E2%80%93Philippines_relations
# /wiki/Philippines%E2%80%93South_Korea_relations
# /wiki/FA-50
# /wiki/Lockheed_T-33
# /wiki/Piper_PA-34_Seneca
# /wiki/Piper_PA-28_Cherokee
# /wiki/Piper_J-5
# /wiki/Fairchild_FC-2
# /wiki/Alenia_C-27J_Spartan
# /wiki/Lockheed_Model_18_Lodestar
# /wiki/Linhas_A%C3%A9reas_Wright
# /wiki/Master_Top_Airlines
# /wiki/Via%C3%A7%C3%A3o_A%C3%A9rea_Bahiana
# /wiki/Industry_in_Brazil
# /wiki/Parna%C3%ADba
# /wiki/S%C3%A3o_Jo%C3%A3o_da_Canabrava
# /wiki/Joaquim_Pires
# /wiki/Jerumenha
# /wiki/Regenera%C3%A7%C3%A3o,_Piau%C3%AD
# /wiki/Canto_do_Buriti
# /wiki/Palmeira_do_Piau%C3%AD
# /wiki/Piracuruca
# /wiki/Pio_IX
# /wiki/UTC%E2%88%923
# /wiki/Daylight_saving_time
# /wiki/Gravitational_time_dilation
# /wiki/Observer_(special_relativity)
# /wiki/Proper_time
# /wiki/Geologic_time_scale
# /wiki/Ludfordian
# /wiki/Mesoarchean
# /wiki/Paleoarchean
# /wiki/Life_(journal)
# /wiki/ISSN_(identifier)
# /wiki/ISO_6943
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-52521cd412f6> in <cell line: 14>()
#      15     newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16     print(newArticle)
# ---> 17     links = getLinks(newArticle)
#
# <ipython-input-4-52521cd412f6> in getLinks(articleUrl)
#       7 random.seed(datetime.datetime.now().strftime('%s'))
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen(f'http://en.wikipedia.org{articleUrl}')
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     517
#     518         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519         response = self._open(req, data)
#     520
#     521         # post-process response
#
# /usr/lib/python3.10/urllib/request.py in _open(self, req, data)
#     534
#     535         protocol = req.type
# --> 536         result = self._call_chain(self.handle_open, protocol, protocol +
#     537                                   '_open', req)
#     538         if result:
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in https_open(self, req)
#    1389
#    1390         def https_open(self, req):
# -> 1391             return self.do_open(http.client.HTTPSConnection, req,
#    1392                 context=self._context, check_hostname=self._check_hostname)
#    1393
#
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1350             except OSError as err: # timeout error
#    1351                 raise URLError(err)
# -> 1352             r = h.getresponse()
#    1353         except:
#    1354             h.close()
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('')
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Special:WhatLinksHere/User_talk:34.168.173.144
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-c5465d2f120f> in <cell line: 17>()
#      15                 pages.add(newPage)
#      16                 getLinks(newPage)
# ---> 17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#      14                 print(newPage)
#      15                 pages.add(newPage)
# ---> 16                 getLinks(newPage)
#      17 getLinks('')
#
# <ipython-input-5-c5465d2f120f> in getLinks(pageUrl)
#       5 pages = set()
#       6 def getLinks(pageUrl):
# ----> 7     html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#       8     bs = BeautifulSoup(html, 'html.parser')
#       9     for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')

    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('/wiki/General-purpose_programming_language')
# Out:
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Main_Page
# Main Page
# <p><i><b><a href="/wiki/Atrociraptor" title="Atrociraptor">Atrociraptor</a></b></i> is a <a href="/wiki/Genus" title="Genus">genus</a> of <a href="/wiki/Dromaeosauridae" title="Dromaeosauridae">dromaeosaurid</a> dinosaur that lived during the <a href="/wiki/Late_Cretaceous" title="Late Cretaceous">Late Cretaceous</a> in what is now <a href="/wiki/Alberta" title="Alberta">Alberta</a>, Canada. The first specimen was discovered in 1995 by the <a href="/wiki/Fossil_collecting" title="Fossil collecting">fossil collector</a> Wayne Marshall in the <a href="/wiki/Horseshoe_Canyon_Formation" title="Horseshoe Canyon Formation">Horseshoe Canyon Formation</a>. In 2004, this became the <a href="/wiki/Holotype" title="Holotype">holotype</a> of the new genus and species <i>Atrociraptor marshalli</i>; the <a href="/wiki/Genus#Use" title="Genus">generic name</a> is <a href="/wiki/Latin" title="Latin">Latin</a> for 'savage robber'. It is estimated to have measured 1.8 to 2 m (5.9 to 6.6 ft) in length and weighed 15 kg (33 lb). It would have had a large sickle-claw on the second toe and <a href="/wiki/Pennaceous_feather" title="Pennaceous feather">pennaceous feathers</a>. <i>Atrociraptor</i> has a deeper face and more strongly backwards-inclined teeth than its contemporary relatives. It is thought to have been specialised for attacking larger prey due to its deep snout. Studies suggest dromaeosaurids used their sickle-claws to restrain prey while dismembering them with the mouth. <i>Atrociraptor</i> dates from around 72.2 to 71.5 million years ago; it survived for more than 2 million years and across a wide geographic area. (<b><a href="/wiki/Atrociraptor" title="Atrociraptor">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p><b>Law and crime</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Random
# Péter Szilágyi (politician, 1981)
# <p><b>Péter Zoltán Szilágyi</b> (born 6 January 1981)<sup class="reference" id="cite_ref-Biography_1-0"><a href="#cite_note-Biography-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup> is a Hungarian jurist and politician, <a class="mw-redirect" href="/wiki/National_Assembly_of_Hungary" title="National Assembly of Hungary">member of the National Assembly</a> (MP) from <a class="mw-redirect" href="/wiki/Politics_Can_Be_Different" title="Politics Can Be Different">Politics Can Be Different</a> (LMP) National List between 2010 and 2014.<sup class="reference" id="cite_ref-Register_2-0"><a href="#cite_note-Register-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup>
# </p>
# /w/index.php?title=P%C3%A9ter_Szil%C3%A1gyi_(politician,_1981)&action=edit
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p>
# <style data-mw-deduplicate="TemplateStyles:r1012508797">.mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p><style data-mw-deduplicate="TemplateStyles:r1239334454">.mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;max-width:100%;overflow:hidden;border:1px solid var(--border-color-base,#a2a9b1);margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;font-weight:bold}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:var(--background-color-interactive,#eaecf0);border:1px solid var(--border-color-subtle,#c8ccd1);border-top:0}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}@media screen{html.skin-theme-clientpref-night .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__main-title{background-color:#24282c}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .introtosingle__main-title{background-color:#24282c}html.skin-theme-clientpref-os .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>This is a list of recent changes to Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Search
# Search
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyContributions
# User contributions for 34.168.173.144
# <p>This IP address is currently blocked.
# The latest block log entry is provided below for reference:
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyTalk
# User talk:34.168.173.144
# <p>This user is currently blocked.
# The latest block log entry is provided below for reference:
# </p>
# /w/index.php?title=User_talk:34.168.173.144&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User_talk:34.168.173.144
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-0966bd882908> in <cell line: 28>()
#      26                 pages.add(newPage)
#      27                 getLinks(newPage)
# ---> 28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#      25                 print(newPage)
#      26                 pages.add(newPage)
# ---> 27                 getLinks(newPage)
#      28 getLinks('/wiki/General-purpose_programming_language')
#
# <ipython-input-6-0966bd882908> in getLinks(pageUrl)
#       5 pages = set()
#       6 def getLinks(pageUrl):
# ----> 7     html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#       8     bs = BeautifulSoup(html, 'html.parser')
#       9     try:
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)

#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
    externalLinks = getExternalLinks(bs, startingPage)
    if not len(externalLinks):
        print('No external links, looking around the site for one')
        internalLinks = getInternalLinks(bs, startingPage)
        return getRandomExternalLink(random.choice(internalLinks))
    else:
        return random.choice(externalLinks)

def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)


followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://itunes.apple.com/us/app/safari-to-go/id881697395
# Random external link is: https://www.oreilly.com/privacy.html
# Random external link is: https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/adequacy-protection-personal-data-non-eu-countries_en
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-5afbf3872f9d> in <cell line: 51>()
#      49
#      50
# ---> 51 followExternalOnly('https://www.oreilly.com/')
#
# <ipython-input-7-5afbf3872f9d> in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# <ipython-input-7-5afbf3872f9d> in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# <ipython-input-7-5afbf3872f9d> in followExternalOnly(startingSite)
#      46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
# ---> 48     followExternalOnly(externalLink)
#      49
#      50
#
# <ipython-input-7-5afbf3872f9d> in followExternalOnly(startingSite)
#      44
#      45 def followExternalOnly(startingSite):
# ---> 46     externalLink = getRandomExternalLink(startingSite)
#      47     print(f'Random external link is: {externalLink}')
#      48     followExternalOnly(externalLink)
#
# <ipython-input-7-5afbf3872f9d> in getRandomExternalLink(startingPage)
#      34
#      35 def getRandomExternalLink(startingPage):
# ---> 36     bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
#      37     externalLinks = getExternalLinks(bs, startingPage)
#      38     if not len(externalLinks):
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     555             http_err = 0
#     556         args = (dict, proto, meth_name) + args
# --> 557         result = self._call_chain(*args)
#     558         if result:
#     559             return result
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     747         fp.close()
#     748
# --> 749         return self.parent.open(new, timeout=req.timeout)
#     750
#     751     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []


def getAllExternalLinks(url):
    bs = BeautifulSoup(urlopen(url), 'html.parser')
    internalLinks = getInternalLinks(bs, url)
    externalLinks = getExternalLinks(bs, url)
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.append(link)
            print(link)

    for link in internalLinks:
        if link not in allIntLinks:
            allIntLinks.append(link)
            getAllExternalLinks(link)


allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
# Out:
# https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://oreilly.id/
# https://learning.oreilly.com/start-trial/
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://learning.oreilly.com/search/?query=author%3A%22Arianne%20Dee%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=suggestion&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.youtube.com/user/OreillyMedia
# https://learning.oreilly.com/search/?query=author%3A%22Ken%20Kousen%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://learning.oreilly.com/search/?query=author%3A%22Bruno%20Gon%C3%A7alves%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Kelsey%20Hightower%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.oreilly.co.jp/index.shtml
# https://www.linkedin.com/company/oreilly-media
# https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://oreilly.hk/
# https://channelstore.roku.com/details/c8a2d0096693eb9455f6ac165003ee06/oreilly
# https://oreillylearning.in/
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# https://www.gsaelibrary.gsa.gov/ElibMain/contractorInfo.do?contractNumber=47QTCA19D0022&contractorName=O%27REILLY+MEDIA%2C+INC&executeQuery=YES
# https://ae.oreilly.com/Modern_Defense_in_Depth
# https://cdn.oreillystatic.com/pdf/OReilly_Capabilities_Statement.pdf
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/model-contracts-transfer-personal-data-third-countries_en
# https://www.safaribooksonline.com/terms/
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/adequacy-protection-personal-data-non-eu-countries_en
# https://tools.google.com/dlpage/gaoptout/
# https://www.dataprivacyframework.gov/s/
# https://edpo.com/gdpr-data-request/
# https://www.safaribooksonline.com/membership-agreement/
# https://ico.org.uk/
# http://archive.oreilly.com/oreillyschool/privacy-policy-version2/
# https://www.dataprivacyframework.gov/s/article/How-to-Submit-a-Complaint-Relating-to-a-Participating-Organization-s-Compliance-with-the-DPF-Principles-dpf
# https://learning.oreilly.com/membership-agreement/
# http://archive.oreilly.com/oreillyschool/privacy-policy/
# https://www.safaribooksonline.com/static/legal/SafariPrivacyPolicy_v3.3_13June2017.a4d9478408f5.pdf
# https://cdn.oreillystatic.com/pdf/SafariPrivacyPolicy_v3.4_23October2017.pdf
# http://www.oreilly.co.jp
# http://www.oreilly.com.cn/
# https://maps.google.com/maps?f=q&hl=en&geocode=&q=1005+Gravenstein+Hwy+N,+Sebastopol,+CA+95472&sll=37.0625,-95.677068&sspn=36.368578,61.435547&ie=UTF8&ll=38.419234,-122.837534&spn=0.008794,0.014999&z=14&iwloc=addr&om=1&source=embed
# https://learning.oreilly.com/topics/
# https://learning.oreilly.com/profile/
# https://learning.oreilly.com/recommendations/
# https://learning.oreilly.com/answers/search/
# https://learning.oreilly.com/assignments/
# https://support.credly.com/hc/en-us/articles/360020964272-How-do-I-share-my-badge-
# https://support.credly.com/hc/en-us/articles/360021222051-What-is-Credly-
# https://support.credly.com/hc/en-us/articles/360021221491-How-can-I-add-my-badge-to-my-LinkedIn-profile-and-share-to-my-feed-
# https://support.credly.com/hc/en-us
# https://learning.oreilly.com/live-events/whats-new-in-software-architecture-designing-tomorrows-data-architecture-with-pramod-sadalage/0642572002741/
# https://learning.oreilly.com/live-events/tech-leadership-tuesday-with-michael-lopp-improving-developer-productivity-with-tara-hernandez/0790145071397/
# https://learning.oreilly.com/interactive/?type=sandbox&type=cloud-sandbox&order_by=created_at&topic_slug=google-cloud-platform-gcp&topic_slug=amazon-web-services-aws&page=1
# https://learning.oreilly.com/live-events/superstreams/
# https://learning.oreilly.com/live-events/architectural-katas-fall-2024/0642572006974/
# https://learning.oreilly.com/search/?q=*&type=book&rows=100
# https://learning.oreilly.com/playlists/b04ccb0d-5c32-4dcb-87f3-ed4022a053d4/
# https://learning.oreilly.com/highlights/
# https://learning.oreilly.com/search/?q=*&rows=100&order_by=_oreilly_popularity
# https://learning.oreilly.com/live-events/tim-oreilly-and-cory-doctorow-on-enshittification-and-the-future-of-ai/0642572001651/
# https://learning.oreilly.com/interactive/?type=scenario&page=1&order_by=created_at
# https://learning.oreilly.com/academy/ai/
# https://learning.oreilly.com/live-events/certification-exam-cram-certified-kubernetes-application-developer-ckad/0642572008016/
# https://learning.oreilly.com/live-events/ai-for-everyone/0642572007782/
# https://learning.oreilly.com/live-events/prompt-to-product-showdown/0642572006797/0642572006796/
# https://learning.oreilly.com/search/?q=*&type=article&type=book&type=journal&type=shortcut&has_sandbox=true&page=1
# https://learning.oreilly.com/search/?q=*&type=playlist&playlist_type=expert&order_by=published_at&rows=10
# https://learning.oreilly.com/search/?q=*&type=course&course_type=on-demand
# https://learning.oreilly.com/live-events/infrastructure-ops-superstream-platform-engineering-best-practices/0790145085614/0790145085606/
# https://learning.oreilly.com/history/
# https://learning.oreilly.com/search/?q=*&type=audiobook&rows=100
# https://learning.oreilly.com/shortcuts/
# https://learning.oreilly.com/playlists/42123a72-1108-40f1-91c0-adbfb9f4983b/
# https://learning.oreilly.com/courses/
# https://cdn.oreillystatic.com/oreilly/pdfs/OReilly_Technical_Health_isnt_Optional.pdf
# https://learning.oreilly.com/search/?q=author%3A%22Neal%20Ford%22&type=*
# https://learning.oreilly.com/search/?q=author%3A%22Arianne%20Dee%22&type=*
# https://learning.oreilly.com/search/?q=author%3A%22Kelsey%20Hightower%22&type=*
# https://learning.oreilly.com/search/?q=author%3A%22Bruno%20Gon%C3%A7alves%22&type=*
# https://learning.oreilly.com/search/?q=author%3A%22Ken%20Kousen%22&type=*
# https://learning.oreilly.com/search/?q=author%3A%22Sari%20Greene%22&type=*
# http://oreilly.com/oreilly/privacy.html
# https://learning.oreilly.com/signup/
# https://www2.deloitte.com/us/en/insights/industry/technology/technology-media-and-telecom-predictions/2022/statistics-show-women-in-technology-are-facing-new-headwinds.html
# https://oreillymedia.zoom.us/webinar/register/WN_fKIo1rbyQ--LzsT32zHt5A#/registration
# https://oreillymedia.zoom.us/webinar/register/4117144256726/WN_cJx4pMloTS6r_4PBmOy43w#/registration
# https://oreillymedia.zoom.us/webinar/register/6617144236108/WN_uvGuOC7mQQuxuWVN5nBAFg#/registration
# https://learning.oreilly.com/team-setup/
# https://oreillymedia.zoom.us/webinar/register/5117144235271/WN_h6luylKGTs-wL0XYTPVAfg#/registration
# https://oreillymedia.zoom.us/webinar/register/2817156387260/WN_5WLe8acrSRKop6gKgW7PMQ#/registration
# https://oreillymedia.zoom.us/webinar/register/7017144278048/WN_uo0O7phFRxGiBCqUI9Ollw#/registration
# https://oreillymedia.zoom.us/webinar/register/6517144293179/WN_Dy_jLuSuRP6cluAAreqzcg#/registration
# https://oreillymedia.zoom.us/webinar/register/1017144283474/WN_7OUg6OtDS7-422Pz4iTQNA#/registration
# https://oreillymedia.zoom.us/webinar/register/5317144185190/WN_kaajxOGOTR-dfIi3oP-aRA#/registration
# https://oreillymedia.zoom.us/webinar/register/3217144187656/WN_iINqOMSKRSufCK_psxFz5w#/registration
# https://oreillymedia.zoom.us/webinar/register/5617144255975/WN_hq8GEOUhRtyM0zXjX4N1rg#/registration
# https://oreillymedia.zoom.us/webinar/register/6617144295588/WN_uatx3uWZSZC_tWchQ_Z_5Q#/registration
# https://oreillymedia.zoom.us/webinar/register/2617144258200/WN_XMcmd7FsTQWiF3OerpVPDw#/registration
# https://oreillymedia.zoom.us/webinar/register/4317144240676/WN_a2mET8wOR_aNju1Fuvpufw#/registration
# https://oreillymedia.zoom.us/webinar/register/4917144240034/WN_eCWJPEL2SryP4-7KDvFAvQ#/registration
# https://oreillymedia.zoom.us/webinar/register/8217144294051/WN_6j92o-qSSoirfeRXNtUXZQ#/registration
# https://oreillymedia.zoom.us/webinar/register/7917144279050/WN_9QhtO2MFQA2CF_bRq0AaGQ#/registration
# https://oreillymedia.zoom.us/webinar/register/4917156393130/WN_kW6pfEA7TMuTs06Xhuxtaw#/registration
# https://oreillymedia.zoom.us/webinar/register/3317144234307/WN_oI3xTjPtQVuucyLUwxAZYQ#/registration
# https://oreillymedia.zoom.us/webinar/register/5317156391991/WN_9ASS6wAfT0ibAcNdf1kvFQ#/registration
# https://oreillymedia.zoom.us/webinar/register/6617144183168/WN_FwiE81hWQ0e2X-6ImTcLzQ#/registration
# https://oreillymedia.zoom.us/webinar/register/5517144286620/WN_BOZu6MHBQZyoc4yi9fco7A#/registration
# https://learning.oreilly.com/live-events/build-a-ci-cd-pipeline/0636920057913/0642572010333/
# https://learning.oreilly.com/library/view/hands-on-large-language/9781098150952/
# https://learning.oreilly.com/scenarios/kubernetes-security-container/9781098136482/
# https://learning.oreilly.com/scenarios/challenge-create-and/9781492096870/
# https://learning.oreilly.com/scenarios/launch-inspect-debug/9781492096825/
# https://learning.oreilly.com/library/view/python-crash-course/9781098156664/
# https://learning.oreilly.com/live-events/microservices-bootcamp/0642572005573/0642572009590/
# https://learning.oreilly.com/live-events/microservice-security/0636920070932/0642572005600/
# https://learning.oreilly.com/live-events/communication-styles-for-distributed-architectures-and-microservices/0636920408406/0642572007923/
# https://learning.oreilly.com/scenarios/challenge-build-an/9781492096955/
# https://learning.oreilly.com/library/view/hands-on-machine-learning/9781098125967/
# https://learning.oreilly.com/interactive/
# https://learning.oreilly.com/library/view/designing-data-intensive-applications/9781491903063/
# https://learning.oreilly.com/search/?query=&extended_publisher_data=true&formats=book&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_orioles=true&include_playlists=true&is_academic_institution_account=false&topics=System%20Administration&sort=popularity
# https://learning.oreilly.com/live-events/google-cloud-associate-cloud-engineer-bootcamp/0642572003483/0642572011450/
# https://learning.oreilly.com/scenarios/securing-containers-with/9781492061649/
# https://learning.oreilly.com/scenarios/build-images-for/9781492096948/
# https://learning.oreilly.com/live-events/containers-in-4-hours/0636920239529/0642572007448/
# https://learning.oreilly.com/attend/
# https://docs.google.com/document/d/1EzvHn4xxVbB8mdlO8gTpwV4tKQPLRkbd8kc73CoSrOo/copy
# https://docs.google.com/document/d/1hDe3pmc8taSPh9pdiGLkTPw21J1lPsoKr-H3dygrYWs/copy
# https://docs.google.com/document/d/16B8ZmpEj-DULGNb8X2NjpQPUnZMWUn5kM1ZBaN7pSUs/copy
# http://radar.oreilly.com/2009/01/work-on-stuff-that-matters-fir.html
# https://learning.oreilly.com/register/
# https://members.oreilly.com/
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&amp;keywords=oreilly&amp;qid=1604964116&amp;s=mobile-apps&amp;sr=1-2
# https://twitter.com/oreillymedia
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-93fd470674d1> in <cell line: 22>()
#      20
#      21 allIntLinks.append('https://oreilly.com')
# ---> 22 getAllExternalLinks('https://www.oreilly.com/')
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#      16         if link not in allIntLinks:
#      17             allIntLinks.append(link)
# ---> 18             getAllExternalLinks(link)
#      19
#      20
#
# <ipython-input-8-93fd470674d1> in getAllExternalLinks(url)
#       5
#       6 def getAllExternalLinks(url):
# ----> 7     bs = BeautifulSoup(urlopen(url), 'html.parser')
#       8     internalLinks = getInternalLinks(bs, url)
#       9     externalLinks = getExternalLinks(bs, url)
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found
